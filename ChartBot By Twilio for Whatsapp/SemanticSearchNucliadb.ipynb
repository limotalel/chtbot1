# %%
! pip install nucliadb-sdk
! pip install -U sentence-transformers
! pip install datasets
# Out:
# Requirement already satisfied: nucliadb-sdk in c:\users\limo\anaconda3\envs\chartbotwhatsapp\lib\site-packages (2.17.0.post461)
# Requirement already satisfied: httpx in c:\users\limo\anaconda3\envs\chartbotwhatsapp\lib\site-packages (from nucliadb-sdk) (0.24.1)
# Requirement already satisfied: requests in c:\users\limo\anaconda3\envs\chartbotwhatsapp\lib\site-packages (from nucliadb-sdk) (2.31.0)
# Requirement already satisfied: nucliadb-models==2.17.0-post461 in c:\users\limo\anaconda3\envs\chartbotwhatsapp\lib\site-packages (from nucliadb-sdk) (2.17.0.post461)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\limo\anaconda3\envs\chartbotwhatsapp\lib\site-packages (from nucliadb-sdk) (1.26.16)
# Requirement already satisfied: orjson in c:\users\limo\anaconda3\envs\chartbotwhatsapp\lib\site-packages (from nucliadb-sdk) (3.9.2)
# Requirement already satisfied: pydantic<2.0,>=1.10.9 in c:\users\limo\anaconda3\envs\chartbotwhatsapp\lib\site-packages (from nucliadb-sdk) (1.10.9)
# Requirement already satisfied: nucliadb-protos==2.17.0-post461 in c:\users\limo\anaconda3\envs\chartbotwhatsapp\lib\site-packages (from nucliadb-models==2.17.0-post461->nucliadb-sdk) (2.17.0.post461)
# Requirement already satisfied: protobuf in c:\users\limo\anaconda3\envs\chartbotwhatsapp\lib\site-packages (from nucliadb-protos==2.17.0-post461->nucliadb-models==2.17.0-post461->nucliadb-sdk) (4.23.4)
# Requirement already satisfied: grpcio>=1.44.0 in c:\users\limo\anaconda3\envs\chartbotwhatsapp\lib\site-packages (from nucliadb-protos==2.17.0-post461->nucliadb-models==2.17.0-post461->nucliadb-sdk) (1.56.0)
# Requirement already satisfied: grpcio-tools>=1.44.0 in c:\users\limo\anaconda3\envs\chartbotwhatsapp\lib\site-packages (from nucliadb-protos==2.17.0-post461->nucliadb-models==2.17.0-post461->nucliadb-sdk) (1.56.0)
# Requirement already satisfied: mypy-protobuf>=3.2.0 in c:\users\limo\anaconda3\envs\chartbotwhatsapp\lib\site-packages (from nucliadb-protos==2.17.0-post461->nucliadb-models==2.17.0-post461->nucliadb-sdk) (3.4.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\limo\anaconda3\envs\chartbotwhatsapp\lib\site-packages (from pydantic<2.0,>=1.10.9->nucliadb-sdk) (4.6.3)
# Requirement already satisfied: certifi in c:\users\limo\anaconda3\envs\chartbotwhatsapp\lib\site-packages (from httpx->nucliadb-sdk) (2023.5.7)
# Requirement already satisfied: httpcore<0.18.0,>=0.15.0 in c:\users\limo\anaconda3\envs\chartbotwhatsapp\lib\site-packages (from httpx->nucliadb-sdk) (0.17.3)
# Requirement already satisfied: idna in c:\users\limo\anaconda3\envs\chartbotwhatsapp\lib\site-packages (from httpx->nucliadb-sdk) (3.4)
# Requirement already satisfied: sniffio in c:\users\limo\anaconda3\envs\chartbotwhatsapp\lib\site-packages (from httpx->nucliadb-sdk) (1.3.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\limo\anaconda3\envs\chartbotwhatsapp\lib\site-packages (from requests->nucliadb-sdk) (3.1.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\limo\anaconda3\envs\chartbotwhatsapp\lib\site-packages (from httpcore<0.18.0,>=0.15.0->httpx->nucliadb-sdk) (0.14.0)
# Requirement already satisfied: anyio<5.0,>=3.0 in c:\users\limo\anaconda3\envs\chartbotwhatsapp\lib\site-packages (from httpcore<0.18.0,>=0.15.0->httpx->nucliadb-sdk) (3.7.0)
# Requirement already satisfied: setuptools in c:\users\limo\appdata\roaming\python\python311\site-packages (from grpcio-tools>=1.44.0->nucliadb-protos==2.17.0-post461->nucliadb-models==2.17.0-post461->nucliadb-sdk) (67.6.1)
# Requirement already satisfied: types-protobuf>=3.20.4 in c:\users\limo\anaconda3\envs\chartbotwhatsapp\lib\site-packages (from mypy-protobuf>=3.2.0->nucliadb-protos==2.17.0-post461->nucliadb-models==2.17.0-post461->nucliadb-sdk) (4.23.0.1)
# [notice] A new release of pip is available: 23.0.1 -> 23.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: sentence-transformers in c:\users\limo\anaconda3\envs\chartbotwhatsapp\lib\site-packages (2.2.2)
# Requirement already satisfied: transformers<5.0.0,>=4.6.0 in c:\users\limo\anaconda3\envs\chartbotwhatsapp\lib\site-packages (from sentence-transformers) (4.30.2)
# Requirement already satisfied: tqdm in c:\users\limo\anaconda3\envs\chartbotwhatsapp\lib\site-packages (from sentence-transformers) (4.65.0)
# Requirement already satisfied: torch>=1.6.0 in c:\users\limo\anaconda3\envs\chartbotwhatsapp\lib\site-packages (from sentence-transformers) (2.0.1)
# Requirement already satisfied: torchvision in c:\users\limo\anaconda3\envs\chartbotwhatsapp\lib\site-packages (from sentence-transformers) (0.15.2)
# Requirement already satisfied: numpy in c:\users\limo\anaconda3\envs\chartbotwhatsapp\lib\site-packages (from sentence-transformers) (1.25.1)
# Requirement already satisfied: scikit-learn in c:\users\limo\anaconda3\envs\chartbotwhatsapp\lib\site-packages (from sentence-transformers) (1.3.0)
# Requirement already satisfied: scipy in c:\users\limo\anaconda3\envs\chartbotwhatsapp\lib\site-packages (from sentence-transformers) (1.11.1)
# Requirement already satisfied: nltk in c:\users\limo\anaconda3\envs\chartbotwhatsapp\lib\site-packages (from sentence-transformers) (3.8.1)
# Requirement already satisfied: sentencepiece in c:\users\limo\anaconda3\envs\chartbotwhatsapp\lib\site-packages (from sentence-transformers) (0.1.99)
# Requirement already satisfied: huggingface-hub>=0.4.0 in c:\users\limo\anaconda3\envs\chartbotwhatsapp\lib\site-packages (from sentence-transformers) (0.16.4)
# Requirement already satisfied: filelock in c:\users\limo\anaconda3\envs\chartbotwhatsapp\lib\site-packages (from huggingface-hub>=0.4.0->sentence-transformers) (3.12.2)
# Requirement already satisfied: fsspec in c:\users\limo\anaconda3\envs\chartbotwhatsapp\lib\site-packages (from huggingface-hub>=0.4.0->sentence-transformers) (2023.6.0)
# Requirement already satisfied: requests in c:\users\limo\anaconda3\envs\chartbotwhatsapp\lib\site-packages (from huggingface-hub>=0.4.0->sentence-transformers) (2.31.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\limo\anaconda3\envs\chartbotwhatsapp\lib\site-packages (from huggingface-hub>=0.4.0->sentence-transformers) (6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\limo\anaconda3\envs\chartbotwhatsapp\lib\site-packages (from huggingface-hub>=0.4.0->sentence-transformers) (4.6.3)
# Requirement already satisfied: packaging>=20.9 in c:\users\limo\anaconda3\envs\chartbotwhatsapp\lib\site-packages (from huggingface-hub>=0.4.0->sentence-transformers) (23.1)
# Requirement already satisfied: sympy in c:\users\limo\anaconda3\envs\chartbotwhatsapp\lib\site-packages (from torch>=1.6.0->sentence-transformers) (1.12)
# Requirement already satisfied: networkx in c:\users\limo\anaconda3\envs\chartbotwhatsapp\lib\site-packages (from torch>=1.6.0->sentence-transformers) (3.1)
# Requirement already satisfied: jinja2 in c:\users\limo\anaconda3\envs\chartbotwhatsapp\lib\site-packages (from torch>=1.6.0->sentence-transformers) (3.1.2)
# Requirement already satisfied: colorama in c:\users\limo\anaconda3\envs\chartbotwhatsapp\lib\site-packages (from tqdm->sentence-transformers) (0.4.6)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\limo\anaconda3\envs\chartbotwhatsapp\lib\site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (2023.6.3)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in c:\users\limo\anaconda3\envs\chartbotwhatsapp\lib\site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (0.13.3)
# Requirement already satisfied: safetensors>=0.3.1 in c:\users\limo\anaconda3\envs\chartbotwhatsapp\lib\site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (0.3.1)
# Requirement already satisfied: click in c:\users\limo\anaconda3\envs\chartbotwhatsapp\lib\site-packages (from nltk->sentence-transformers) (8.1.3)
# Requirement already satisfied: joblib in c:\users\limo\anaconda3\envs\chartbotwhatsapp\lib\site-packages (from nltk->sentence-transformers) (1.3.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\limo\anaconda3\envs\chartbotwhatsapp\lib\site-packages (from scikit-learn->sentence-transformers) (3.2.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\limo\anaconda3\envs\chartbotwhatsapp\lib\site-packages (from torchvision->sentence-transformers) (10.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\limo\anaconda3\envs\chartbotwhatsapp\lib\site-packages (from jinja2->torch>=1.6.0->sentence-transformers) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\limo\anaconda3\envs\chartbotwhatsapp\lib\site-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\limo\anaconda3\envs\chartbotwhatsapp\lib\site-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\limo\anaconda3\envs\chartbotwhatsapp\lib\site-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\limo\anaconda3\envs\chartbotwhatsapp\lib\site-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (2023.5.7)
# Requirement already satisfied: mpmath>=0.19 in c:\users\limo\anaconda3\envs\chartbotwhatsapp\lib\site-packages (from sympy->torch>=1.6.0->sentence-transformers) (1.3.0)
# [notice] A new release of pip is available: 23.0.1 -> 23.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Collecting datasets
#   Downloading datasets-2.13.1-py3-none-any.whl (486 kB)
#      -------------------------------------- 486.2/486.2 kB 1.3 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in c:\users\limo\anaconda3\envs\chartbotwhatsapp\lib\site-packages (from datasets) (1.25.1)
# Collecting pyarrow>=8.0.0
#   Downloading pyarrow-12.0.1-cp311-cp311-win_amd64.whl (21.5 MB)
#      ---------------------------------------- 21.5/21.5 MB 1.2 MB/s eta 0:00:00
# Collecting dill<0.3.7,>=0.3.0
#   Downloading dill-0.3.6-py3-none-any.whl (110 kB)
#      ------------------------------------ 110.5/110.5 kB 920.0 kB/s eta 0:00:00
# Collecting pandas
#   Downloading pandas-2.0.3-cp311-cp311-win_amd64.whl (10.6 MB)
#      ---------------------------------------- 10.6/10.6 MB 1.0 MB/s eta 0:00:00
# Requirement already satisfied: requests>=2.19.0 in c:\users\limo\anaconda3\envs\chartbotwhatsapp\lib\site-packages (from datasets) (2.31.0)
# Requirement already satisfied: tqdm>=4.62.1 in c:\users\limo\anaconda3\envs\chartbotwhatsapp\lib\site-packages (from datasets) (4.65.0)
# Collecting xxhash
#   Downloading xxhash-3.2.0-cp311-cp311-win_amd64.whl (30 kB)
# Collecting multiprocess
#   Downloading multiprocess-0.70.14-py310-none-any.whl (134 kB)
#      ------------------------------------ 134.3/134.3 kB 880.0 kB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]>=2021.11.1 in c:\users\limo\anaconda3\envs\chartbotwhatsapp\lib\site-packages (from datasets) (2023.6.0)
# Requirement already satisfied: aiohttp in c:\users\limo\anaconda3\envs\chartbotwhatsapp\lib\site-packages (from datasets) (3.8.4)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.11.0 in c:\users\limo\anaconda3\envs\chartbotwhatsapp\lib\site-packages (from datasets) (0.16.4)
# Requirement already satisfied: packaging in c:\users\limo\anaconda3\envs\chartbotwhatsapp\lib\site-packages (from datasets) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\limo\anaconda3\envs\chartbotwhatsapp\lib\site-packages (from datasets) (6.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\limo\anaconda3\envs\chartbotwhatsapp\lib\site-packages (from aiohttp->datasets) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in c:\users\limo\anaconda3\envs\chartbotwhatsapp\lib\site-packages (from aiohttp->datasets) (3.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\limo\anaconda3\envs\chartbotwhatsapp\lib\site-packages (from aiohttp->datasets) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in c:\users\limo\anaconda3\envs\chartbotwhatsapp\lib\site-packages (from aiohttp->datasets) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\limo\anaconda3\envs\chartbotwhatsapp\lib\site-packages (from aiohttp->datasets) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\limo\anaconda3\envs\chartbotwhatsapp\lib\site-packages (from aiohttp->datasets) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\limo\anaconda3\envs\chartbotwhatsapp\lib\site-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: filelock in c:\users\limo\anaconda3\envs\chartbotwhatsapp\lib\site-packages (from huggingface-hub<1.0.0,>=0.11.0->datasets) (3.12.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\limo\anaconda3\envs\chartbotwhatsapp\lib\site-packages (from huggingface-hub<1.0.0,>=0.11.0->datasets) (4.6.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\limo\anaconda3\envs\chartbotwhatsapp\lib\site-packages (from requests>=2.19.0->datasets) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\limo\anaconda3\envs\chartbotwhatsapp\lib\site-packages (from requests>=2.19.0->datasets) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\limo\anaconda3\envs\chartbotwhatsapp\lib\site-packages (from requests>=2.19.0->datasets) (2023.5.7)
# Requirement already satisfied: colorama in c:\users\limo\anaconda3\envs\chartbotwhatsapp\lib\site-packages (from tqdm>=4.62.1->datasets) (0.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\limo\anaconda3\envs\chartbotwhatsapp\lib\site-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\limo\anaconda3\envs\chartbotwhatsapp\lib\site-packages (from pandas->datasets) (2023.3)
# Collecting tzdata>=2022.1
#   Downloading tzdata-2023.3-py2.py3-none-any.whl (341 kB)
#      ------------------------------------ 341.8/341.8 kB 966.7 kB/s eta 0:00:00
# Requirement already satisfied: six>=1.5 in c:\users\limo\anaconda3\envs\chartbotwhatsapp\lib\site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Installing collected packages: xxhash, tzdata, pyarrow, dill, pandas, multiprocess, datasets
# Successfully installed datasets-2.13.1 dill-0.3.6 multiprocess-0.70.14 pandas-2.0.3 pyarrow-12.0.1 tzdata-2023.3 xxhash-3.2.0
# [notice] A new release of pip is available: 23.0.1 -> 23.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ### Setup nucliaDB

# %%
! pip install nucliadb
# Out:
# Collecting nucliadb
#   Using cached nucliadb-2.17.0.post464-py3-none-any.whl (547 kB)
# Collecting uvicorn<0.19.0
#   Using cached uvicorn-0.18.3-py3-none-any.whl (57 kB)
# Collecting pydantic-argparse
#   Using cached pydantic_argparse-0.8.0-py3-none-any.whl (25 kB)
# Collecting nucliadb-node-binding>=0.7.5
#   Using cached nucliadb_node_binding-0.7.9-cp311-none-win_amd64.whl (5.2 MB)
# Requirement already satisfied: aiohttp>=3.8.1 in c:\users\limo\anaconda3\envs\chartbotwhatsapp\lib\site-packages (from nucliadb) (3.8.4)
# Collecting lru-dict>=1.1.7
#   Using cached lru_dict-1.2.0-cp311-cp311-win_amd64.whl (12 kB)
# Collecting backoff
#   Using cached backoff-2.2.1-py3-none-any.whl (15 kB)
# Collecting aiofiles>=0.8.0
#   Using cached aiofiles-23.1.0-py3-none-any.whl (14 kB)
# Collecting types-aiofiles>=0.8.3
#   Using cached types_aiofiles-23.1.0.5-py3-none-any.whl (8.8 kB)
# Requirement already satisfied: protobuf>=3.20.2 in c:\users\limo\anaconda3\envs\chartbotwhatsapp\lib\site-packages (from nucliadb) (4.23.4)
# Collecting types-protobuf<4.0,>=3.19.20
#   Using cached types_protobuf-3.20.4.6-py3-none-any.whl (60 kB)
# Requirement already satisfied: grpcio>=1.44.0 in c:\users\limo\anaconda3\envs\chartbotwhatsapp\lib\site-packages (from nucliadb) (1.56.0)
# Collecting grpcio-health-checking>=1.44.0
#   Using cached grpcio_health_checking-1.56.2-py3-none-any.whl (8.5 kB)
# Collecting grpcio-channelz>=1.44.0
#   Using cached grpcio_channelz-1.56.2-py3-none-any.whl (10 kB)
# Collecting grpcio-status>=1.44.0
#   Using cached grpcio_status-1.56.2-py3-none-any.whl (5.1 kB)
# Requirement already satisfied: grpcio-tools>=1.44.0 in c:\users\limo\anaconda3\envs\chartbotwhatsapp\lib\site-packages (from nucliadb) (1.56.0)
# Collecting grpcio-testing>=1.44.0
#   Using cached grpcio_testing-1.56.2-py3-none-any.whl (23 kB)
# Collecting grpcio-reflection>=1.44.0
#   Using cached grpcio_reflection-1.56.2-py3-none-any.whl (11 kB)
# Requirement already satisfied: orjson>=3.6.7 in c:\users\limo\anaconda3\envs\chartbotwhatsapp\lib\site-packages (from nucliadb) (3.9.2)
# Collecting types-setuptools
#   Using cached types_setuptools-68.0.0.3-py3-none-any.whl (50 kB)
# Requirement already satisfied: pydantic<2.0,>=1.9.0 in c:\users\limo\anaconda3\envs\chartbotwhatsapp\lib\site-packages (from nucliadb) (1.10.9)
# Collecting aiobotocore>=2.1.1
#   Using cached aiobotocore-2.5.2-py3-none-any.whl (72 kB)
# Collecting aioboto3
#   Using cached aioboto3-11.2.0-py3-none-any.whl (32 kB)
# Collecting botocore
#   Using cached botocore-1.31.7-py3-none-any.whl (11.0 MB)
# Collecting google-cloud-storage
#   Using cached google_cloud_storage-2.10.0-py2.py3-none-any.whl (114 kB)
# Collecting gcloud
#   Using cached gcloud-0.18.3.tar.gz (454 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting oauth2client
#   Using cached oauth2client-4.1.3-py2.py3-none-any.whl (98 kB)
# Collecting fastapi-versioning>=0.10.0
#   Using cached fastapi_versioning-0.10.0-py3-none-any.whl (4.9 kB)
# Collecting fastapi<0.89.0,>=0.75.0
#   Using cached fastapi-0.88.0-py3-none-any.whl (55 kB)
# Collecting sentry-sdk>=1.5.12
#   Using cached sentry_sdk-1.28.1-py2.py3-none-any.whl (214 kB)
# Requirement already satisfied: pyjwt>=2.4.0 in c:\users\limo\anaconda3\envs\chartbotwhatsapp\lib\site-packages (from nucliadb) (2.7.0)
# Collecting mmh3>=3.0.0
#   Using cached mmh3-4.0.1-cp311-cp311-win_amd64.whl (36 kB)
# Requirement already satisfied: httpx>=0.23.0 in c:\users\limo\anaconda3\envs\chartbotwhatsapp\lib\site-packages (from nucliadb) (0.24.1)
# Collecting types-pkg-resources>=0.1.3
#   Using cached types_pkg_resources-0.1.3-py2.py3-none-any.whl (4.8 kB)
# Collecting grpc-stubs>=1.24.7
#   Using cached grpc_stubs-1.53.0.2-py3-none-any.whl (20 kB)
# Collecting aiodns>=3.0.0
#   Using cached aiodns-3.0.0-py3-none-any.whl (5.0 kB)
# Collecting types-orjson
#   Using cached types_orjson-3.6.2-py3-none-any.whl (2.2 kB)
# Collecting nucliadb-telemetry>=1.12.0
#   Using cached nucliadb_telemetry-1.12.0-py3-none-any.whl (68 kB)
# Collecting nucliadb-utils[cache,fastapi,storages]==2.17.0-post464
#   Using cached nucliadb_utils-2.17.0.post464-py3-none-any.whl (96 kB)
# Collecting nucliadb-protos==2.17.0-post464
#   Using cached nucliadb_protos-2.17.0.post464-py3-none-any.whl (94 kB)
# Requirement already satisfied: nucliadb-models>=2.15.1.post353 in c:\users\limo\anaconda3\envs\chartbotwhatsapp\lib\site-packages (from nucliadb) (2.17.0.post461)
# Collecting nucliadb-contributor-assets~=1.0.0
#   Using cached nucliadb_contributor_assets-1.0.0.post899-py3-none-any.whl (792 kB)
# Collecting asyncpg>=0.27.0
#   Using cached asyncpg-0.28.0-cp311-cp311-win_amd64.whl (534 kB)
# Collecting nucliadb
#   Using cached nucliadb-2.17.0.post462-py3-none-any.whl (547 kB)
# Collecting nucliadb-utils[cache,fastapi,storages]==2.17.0-post462
#   Using cached nucliadb_utils-2.17.0.post462-py3-none-any.whl (96 kB)
# Collecting nucliadb-protos==2.17.0-post462
#   Using cached nucliadb_protos-2.17.0.post462-py3-none-any.whl (94 kB)
# Collecting nucliadb
#   Using cached nucliadb-2.17.0.post461-py3-none-any.whl (547 kB)
# Collecting nucliadb-utils[cache,fastapi,storages]==2.17.0-post461
#   Using cached nucliadb_utils-2.17.0.post461-py3-none-any.whl (96 kB)
# Requirement already satisfied: nucliadb-protos==2.17.0-post461 in c:\users\limo\anaconda3\envs\chartbotwhatsapp\lib\site-packages (from nucliadb) (2.17.0.post461)
# Collecting nucliadb
#   Using cached nucliadb-2.17.0.post460-py3-none-any.whl (547 kB)
# Collecting nucliadb-utils[cache,fastapi,storages]==2.17.0-post460
#   Using cached nucliadb_utils-2.17.0.post460-py3-none-any.whl (96 kB)
# Collecting nucliadb-protos==2.17.0-post460
#   Using cached nucliadb_protos-2.17.0.post460-py3-none-any.whl (94 kB)
# Collecting nucliadb
#   Using cached nucliadb-2.17.0.post458-py3-none-any.whl (547 kB)
# Collecting nucliadb-utils[cache,fastapi,storages]==2.17.0-post458
#   Using cached nucliadb_utils-2.17.0.post458-py3-none-any.whl (96 kB)
# Collecting nucliadb-protos==2.17.0-post458
#   Using cached nucliadb_protos-2.17.0.post458-py3-none-any.whl (94 kB)
# Collecting nucliadb
#   Using cached nucliadb-2.17.0.post457-py3-none-any.whl (547 kB)
# Collecting nucliadb-utils[cache,fastapi,storages]==2.17.0-post457
#   Using cached nucliadb_utils-2.17.0.post457-py3-none-any.whl (96 kB)
# Collecting nucliadb-protos==2.17.0-post457
#   Using cached nucliadb_protos-2.17.0.post457-py3-none-any.whl (94 kB)
# Collecting nucliadb
#   Using cached nucliadb-2.17.0.post456-py3-none-any.whl (547 kB)
# Collecting nucliadb-utils[cache,fastapi,storages]==2.17.0-post456
#   Using cached nucliadb_utils-2.17.0.post456-py3-none-any.whl (96 kB)
# Collecting nucliadb-protos==2.17.0-post456
#   Using cached nucliadb_protos-2.17.0.post456-py3-none-any.whl (94 kB)
# Collecting nucliadb
#   Using cached nucliadb-2.17.0.post454-py3-none-any.whl (547 kB)
# Collecting nucliadb-utils[cache,fastapi,storages]==2.17.0-post454
#   Using cached nucliadb_utils-2.17.0.post454-py3-none-any.whl (96 kB)
# Collecting nucliadb-protos==2.17.0-post454
#   Using cached nucliadb_protos-2.17.0.post454-py3-none-any.whl (94 kB)
# Collecting nucliadb
#   Using cached nucliadb-2.17.0.post452-py3-none-any.whl (547 kB)
# Collecting nucliadb-utils[cache,fastapi,storages]==2.17.0-post452
#   Using cached nucliadb_utils-2.17.0.post452-py3-none-any.whl (96 kB)
# Collecting nucliadb-protos==2.17.0-post452
#   Using cached nucliadb_protos-2.17.0.post452-py3-none-any.whl (94 kB)
# Collecting nucliadb
#   Using cached nucliadb-2.17.0.post451-py3-none-any.whl (546 kB)
# Collecting nucliadb-utils[cache,fastapi,storages]==2.17.0-post451
#   Using cached nucliadb_utils-2.17.0.post451-py3-none-any.whl (96 kB)
# Collecting nucliadb-protos==2.17.0-post451
#   Using cached nucliadb_protos-2.17.0.post451-py3-none-any.whl (94 kB)
# Collecting nucliadb
#   Using cached nucliadb-2.17.0.post448-py3-none-any.whl (536 kB)
# Collecting nucliadb-utils[cache,fastapi,storages]==2.17.0-post448
#   Using cached nucliadb_utils-2.17.0.post448-py3-none-any.whl (96 kB)
# Collecting nucliadb-protos==2.17.0-post448
#   Using cached nucliadb_protos-2.17.0.post448-py3-none-any.whl (94 kB)
# Collecting nucliadb
#   Using cached nucliadb-2.17.0.post447-py3-none-any.whl (536 kB)
# Collecting nucliadb-utils[cache,fastapi,storages]==2.17.0-post447
#   Using cached nucliadb_utils-2.17.0.post447-py3-none-any.whl (96 kB)
# Collecting nucliadb-protos==2.17.0-post447
#   Using cached nucliadb_protos-2.17.0.post447-py3-none-any.whl (94 kB)
# Collecting nucliadb
#   Using cached nucliadb-2.17.0.post446-py3-none-any.whl (535 kB)
# Collecting nucliadb-utils[cache,fastapi,storages]==2.17.0-post446
#   Using cached nucliadb_utils-2.17.0.post446-py3-none-any.whl (96 kB)
# Collecting nucliadb-protos==2.17.0-post446
#   Using cached nucliadb_protos-2.17.0.post446-py3-none-any.whl (94 kB)
# Collecting nucliadb
#   Using cached nucliadb-2.17.0.post445-py3-none-any.whl (533 kB)
# Collecting nucliadb-utils[cache,fastapi,storages]==2.17.0-post445
#   Using cached nucliadb_utils-2.17.0.post445-py3-none-any.whl (96 kB)
# Collecting nucliadb-protos==2.17.0-post445
#   Using cached nucliadb_protos-2.17.0.post445-py3-none-any.whl (94 kB)
# Collecting nucliadb
#   Using cached nucliadb-2.17.0.post444-py3-none-any.whl (533 kB)
# Collecting nucliadb-utils[cache,fastapi,storages]==2.17.0-post444
#   Using cached nucliadb_utils-2.17.0.post444-py3-none-any.whl (96 kB)
# Collecting nucliadb-protos==2.17.0-post444
#   Using cached nucliadb_protos-2.17.0.post444-py3-none-any.whl (94 kB)
# Collecting nucliadb
#   Using cached nucliadb-2.17.0.post443-py3-none-any.whl (533 kB)
# Collecting nucliadb-utils[cache,fastapi,storages]==2.17.0-post443
#   Using cached nucliadb_utils-2.17.0.post443-py3-none-any.whl (96 kB)
# Collecting nucliadb-protos==2.17.0-post443
#   Using cached nucliadb_protos-2.17.0.post443-py3-none-any.whl (94 kB)
# Collecting nucliadb
#   Using cached nucliadb-2.17.0.post442-py3-none-any.whl (533 kB)
# Collecting nucliadb-utils[cache,fastapi,storages]==2.17.0-post442
#   Using cached nucliadb_utils-2.17.0.post442-py3-none-any.whl (96 kB)
# Collecting nucliadb-protos==2.17.0-post442
#   Using cached nucliadb_protos-2.17.0.post442-py3-none-any.whl (94 kB)
# Collecting nucliadb
#   Using cached nucliadb-2.17.0.post441-py3-none-any.whl (533 kB)
# Collecting nucliadb-utils[cache,fastapi,storages]==2.17.0-post441
#   Using cached nucliadb_utils-2.17.0.post441-py3-none-any.whl (96 kB)
# Collecting nucliadb-protos==2.17.0-post441
#   Using cached nucliadb_protos-2.17.0.post441-py3-none-any.whl (94 kB)
# Collecting nucliadb
#   Using cached nucliadb-2.17.0.post440-py3-none-any.whl (533 kB)
# Collecting nucliadb-utils[cache,fastapi,storages]==2.17.0-post440
#   Using cached nucliadb_utils-2.17.0.post440-py3-none-any.whl (96 kB)
# Collecting nucliadb-protos==2.17.0-post440
#   Using cached nucliadb_protos-2.17.0.post440-py3-none-any.whl (94 kB)
# Collecting nucliadb
#   Using cached nucliadb-2.17.0.post439-py3-none-any.whl (533 kB)
# Collecting nucliadb-utils[cache,fastapi,storages]==2.17.0-post439
#   Using cached nucliadb_utils-2.17.0.post439-py3-none-any.whl (96 kB)
# Collecting nucliadb-protos==2.17.0-post439
#   Using cached nucliadb_protos-2.17.0.post439-py3-none-any.whl (94 kB)
# Collecting nucliadb
#   Using cached nucliadb-2.17.0.post438-py3-none-any.whl (534 kB)
# Collecting nucliadb-utils[cache,fastapi,storages]==2.17.0-post438
#   Using cached nucliadb_utils-2.17.0.post438-py3-none-any.whl (96 kB)
# Collecting nucliadb-protos==2.17.0-post438
#   Using cached nucliadb_protos-2.17.0.post438-py3-none-any.whl (94 kB)
# Collecting nucliadb
#   Using cached nucliadb-2.17.0.post437-py3-none-any.whl (533 kB)
# Collecting nucliadb-utils[cache,fastapi,storages]==2.17.0-post437
#   Using cached nucliadb_utils-2.17.0.post437-py3-none-any.whl (96 kB)
# Collecting nucliadb-protos==2.17.0-post437
#   Using cached nucliadb_protos-2.17.0.post437-py3-none-any.whl (94 kB)
# Collecting nucliadb
#   Using cached nucliadb-2.17.0.post436-py3-none-any.whl (533 kB)
# Collecting nucliadb-utils[cache,fastapi,storages]==2.17.0-post436
#   Using cached nucliadb_utils-2.17.0.post436-py3-none-any.whl (96 kB)
# Collecting nucliadb-protos==2.17.0-post436
#   Using cached nucliadb_protos-2.17.0.post436-py3-none-any.whl (94 kB)
# Collecting nucliadb
#   Using cached nucliadb-2.17.0.post435-py3-none-any.whl (533 kB)
# Collecting nucliadb-utils[cache,fastapi,storages]==2.17.0-post435
#   Using cached nucliadb_utils-2.17.0.post435-py3-none-any.whl (96 kB)
# Collecting nucliadb-protos==2.17.0-post435
#   Using cached nucliadb_protos-2.17.0.post435-py3-none-any.whl (94 kB)
# Collecting nucliadb
#   Using cached nucliadb-2.17.0.post434-py3-none-any.whl (532 kB)
# Collecting nucliadb-utils[cache,fastapi,storages]==2.17.0-post434
#   Using cached nucliadb_utils-2.17.0.post434-py3-none-any.whl (96 kB)
# Collecting nucliadb-protos==2.17.0-post434
#   Using cached nucliadb_protos-2.17.0.post434-py3-none-any.whl (94 kB)
# Collecting nucliadb
#   Using cached nucliadb-2.17.0.post433-py3-none-any.whl (532 kB)
# Collecting nucliadb-utils[cache,fastapi,storages]==2.17.0-post433
#   Using cached nucliadb_utils-2.17.0.post433-py3-none-any.whl (96 kB)
# Collecting nucliadb-protos==2.17.0-post433
#   Using cached nucliadb_protos-2.17.0.post433-py3-none-any.whl (94 kB)
# Collecting nucliadb
#   Using cached nucliadb-2.17.0.post432-py3-none-any.whl (532 kB)
# Collecting nucliadb-utils[cache,fastapi,storages]==2.17.0-post432
#   Using cached nucliadb_utils-2.17.0.post432-py3-none-any.whl (96 kB)
# Collecting nucliadb-protos==2.17.0-post432
#   Using cached nucliadb_protos-2.17.0.post432-py3-none-any.whl (94 kB)
# Collecting nucliadb
#   Using cached nucliadb-2.17.0.post431-py3-none-any.whl (532 kB)
# Collecting nucliadb-utils[cache,fastapi,storages]==2.17.0-post431
#   Using cached nucliadb_utils-2.17.0.post431-py3-none-any.whl (96 kB)
# Collecting nucliadb-protos==2.17.0-post431
#   Using cached nucliadb_protos-2.17.0.post431-py3-none-any.whl (94 kB)
# Collecting nucliadb
#   Using cached nucliadb-2.17.0.post430-py3-none-any.whl (532 kB)
# Collecting nucliadb-utils[cache,fastapi,storages]==2.17.0-post430
#   Using cached nucliadb_utils-2.17.0.post430-py3-none-any.whl (96 kB)
# Collecting nucliadb-protos==2.17.0-post430
#   Using cached nucliadb_protos-2.17.0.post430-py3-none-any.whl (94 kB)
# Collecting nucliadb
#   Using cached nucliadb-2.17.0.post428-py3-none-any.whl (532 kB)
# Collecting nucliadb-utils[cache,fastapi,storages]==2.17.0-post428
#   Using cached nucliadb_utils-2.17.0.post428-py3-none-any.whl (96 kB)
# Collecting nucliadb-protos==2.17.0-post428
#   Using cached nucliadb_protos-2.17.0.post428-py3-none-any.whl (94 kB)
# Collecting nucliadb
#   Using cached nucliadb-2.17.0.post426-py3-none-any.whl (532 kB)
# Collecting nucliadb-utils[cache,fastapi,storages]==2.17.0-post426
#   Using cached nucliadb_utils-2.17.0.post426-py3-none-any.whl (96 kB)
# Collecting nucliadb-protos==2.17.0-post426
#   Using cached nucliadb_protos-2.17.0.post426-py3-none-any.whl (94 kB)
# Collecting nucliadb
#   Using cached nucliadb-2.17.0.post425-py3-none-any.whl (521 kB)
# Collecting nucliadb-utils[cache,fastapi,storages]==2.17.0-post425
#   Using cached nucliadb_utils-2.17.0.post425-py3-none-any.whl (96 kB)
# Collecting nucliadb-protos==2.17.0-post425
#   Using cached nucliadb_protos-2.17.0.post425-py3-none-any.whl (94 kB)
# Collecting nucliadb
#   Using cached nucliadb-2.17.0.post424-py3-none-any.whl (521 kB)
# Collecting nucliadb-utils[cache,fastapi,storages]==2.17.0-post424
#   Using cached nucliadb_utils-2.17.0.post424-py3-none-any.whl (96 kB)
# Collecting nucliadb-protos==2.17.0-post424
#   Using cached nucliadb_protos-2.17.0.post424-py3-none-any.whl (94 kB)
# Collecting nucliadb
#   Using cached nucliadb-2.17.0.post423-py3-none-any.whl (521 kB)
# Collecting nucliadb-utils[cache,fastapi,storages]==2.17.0-post423
#   Using cached nucliadb_utils-2.17.0.post423-py3-none-any.whl (96 kB)
# Collecting nucliadb-protos==2.17.0-post423
#   Using cached nucliadb_protos-2.17.0.post423-py3-none-any.whl (94 kB)
# Collecting nucliadb
#   Using cached nucliadb-2.17.0.post422-py3-none-any.whl (521 kB)
# Collecting nucliadb-utils[cache,fastapi,storages]==2.17.0-post422
#   Using cached nucliadb_utils-2.17.0.post422-py3-none-any.whl (96 kB)
# Collecting nucliadb-protos==2.17.0-post422
#   Using cached nucliadb_protos-2.17.0.post422-py3-none-any.whl (94 kB)
# Collecting nucliadb
#   Using cached nucliadb-2.17.0.post421-py3-none-any.whl (521 kB)
# Collecting nucliadb-utils[cache,fastapi,storages]==2.17.0-post421
#   Using cached nucliadb_utils-2.17.0.post421-py3-none-any.whl (96 kB)
# Collecting nucliadb-protos==2.17.0-post421
#   Using cached nucliadb_protos-2.17.0.post421-py3-none-any.whl (94 kB)
# Collecting nucliadb
#   Using cached nucliadb-2.17.0.post420-py3-none-any.whl (521 kB)
# Collecting nucliadb-utils[cache,fastapi,storages]==2.17.0-post420
#   Using cached nucliadb_utils-2.17.0.post420-py3-none-any.whl (96 kB)
# Collecting nucliadb-protos==2.17.0-post420
#   Using cached nucliadb_protos-2.17.0.post420-py3-none-any.whl (94 kB)
# Collecting nucliadb
#   Using cached nucliadb-2.17.0.post419-py3-none-any.whl (521 kB)
# Collecting nucliadb-utils[cache,fastapi,storages]==2.17.0-post419
#   Using cached nucliadb_utils-2.17.0.post419-py3-none-any.whl (96 kB)
# Collecting nucliadb-protos==2.17.0-post419
#   Using cached nucliadb_protos-2.17.0.post419-py3-none-any.whl (94 kB)
# Collecting nucliadb
#   Using cached nucliadb-2.17.0.post418-py3-none-any.whl (521 kB)
# Collecting nucliadb-utils[cache,fastapi,storages]==2.17.0-post418
#   Using cached nucliadb_utils-2.17.0.post418-py3-none-any.whl (96 kB)
# Collecting nucliadb-protos==2.17.0-post418
#   Using cached nucliadb_protos-2.17.0.post418-py3-none-any.whl (94 kB)
# Collecting nucliadb
#   Using cached nucliadb-2.17.0.post417-py3-none-any.whl (515 kB)
# Collecting nucliadb-utils[cache,fastapi,storages]==2.17.0-post417
#   Using cached nucliadb_utils-2.17.0.post417-py3-none-any.whl (96 kB)
# Collecting nucliadb-protos==2.17.0-post417
#   Using cached nucliadb_protos-2.17.0.post417-py3-none-any.whl (93 kB)
# Collecting nucliadb
#   Using cached nucliadb-2.17.0.post416-py3-none-any.whl (515 kB)
# Collecting nucliadb-utils[cache,fastapi,storages]==2.17.0-post416
#   Using cached nucliadb_utils-2.17.0.post416-py3-none-any.whl (96 kB)
# Collecting nucliadb-protos==2.17.0-post416
#   Using cached nucliadb_protos-2.17.0.post416-py3-none-any.whl (93 kB)
# Collecting nucliadb
#   Using cached nucliadb-2.17.0.post414-py3-none-any.whl (516 kB)
# Collecting nucliadb-utils[cache,fastapi,storages]==2.17.0-post414
#   Using cached nucliadb_utils-2.17.0.post414-py3-none-any.whl (96 kB)
# Collecting nucliadb-protos==2.17.0-post414
#   Using cached nucliadb_protos-2.17.0.post414-py3-none-any.whl (93 kB)
# Collecting nucliadb
#   Using cached nucliadb-2.17.0.post413-py3-none-any.whl (516 kB)
# Collecting nucliadb-utils[cache,fastapi,storages]==2.17.0-post413
#   Using cached nucliadb_utils-2.17.0.post413-py3-none-any.whl (96 kB)
# Collecting nucliadb-protos==2.17.0-post413
#   Using cached nucliadb_protos-2.17.0.post413-py3-none-any.whl (93 kB)
# Collecting nucliadb
#   Using cached nucliadb-2.17.0.post412-py3-none-any.whl (515 kB)
# Collecting nucliadb-utils[cache,fastapi,storages]==2.17.0-post412
#   Using cached nucliadb_utils-2.17.0.post412-py3-none-any.whl (96 kB)
# Collecting nucliadb-protos==2.17.0-post412
#   Using cached nucliadb_protos-2.17.0.post412-py3-none-any.whl (93 kB)
# Collecting nucliadb
#   Using cached nucliadb-2.17.0.post410-py3-none-any.whl (514 kB)
# Collecting nucliadb-utils[cache,fastapi,storages]==2.17.0-post410
#   Using cached nucliadb_utils-2.17.0.post410-py3-none-any.whl (96 kB)
# Collecting nucliadb-protos==2.17.0-post410
#   Using cached nucliadb_protos-2.17.0.post410-py3-none-any.whl (93 kB)
# Collecting nucliadb
#   Using cached nucliadb-2.17.0.post409-py3-none-any.whl (514 kB)
# Collecting nucliadb-utils[cache,fastapi,storages]==2.17.0-post409
#   Using cached nucliadb_utils-2.17.0.post409-py3-none-any.whl (96 kB)
# Collecting nucliadb-protos==2.17.0-post409
#   Using cached nucliadb_protos-2.17.0.post409-py3-none-any.whl (93 kB)
# Collecting nucliadb
#   Using cached nucliadb-2.17.0.post408-py3-none-any.whl (515 kB)
# Collecting nucliadb-utils[cache,fastapi,storages]==2.17.0-post408
#   Using cached nucliadb_utils-2.17.0.post408-py3-none-any.whl (96 kB)
# Collecting nucliadb-protos==2.17.0-post408
#   Using cached nucliadb_protos-2.17.0.post408-py3-none-any.whl (93 kB)
# Collecting nucliadb
#   Using cached nucliadb-2.17.0.post407-py3-none-any.whl (515 kB)
# Collecting nucliadb-utils[cache,fastapi,storages]==2.17.0-post407
#   Using cached nucliadb_utils-2.17.0.post407-py3-none-any.whl (96 kB)
# Collecting nucliadb-protos==2.17.0-post407
#   Using cached nucliadb_protos-2.17.0.post407-py3-none-any.whl (93 kB)
# Collecting nucliadb
#   Using cached nucliadb-2.17.0.post405-py3-none-any.whl (514 kB)
# Collecting nucliadb-utils[cache,fastapi,storages]==2.17.0-post405
#   Using cached nucliadb_utils-2.17.0.post405-py3-none-any.whl (96 kB)
# Collecting nucliadb-protos==2.17.0-post405
#   Using cached nucliadb_protos-2.17.0.post405-py3-none-any.whl (93 kB)
# Collecting nucliadb
#   Using cached nucliadb-2.17.0.post404-py3-none-any.whl (514 kB)
# Collecting nucliadb-utils[cache,fastapi,storages]==2.17.0-post404
#   Using cached nucliadb_utils-2.17.0.post404-py3-none-any.whl (96 kB)
# Collecting nucliadb-protos==2.17.0-post404
#   Using cached nucliadb_protos-2.17.0.post404-py3-none-any.whl (93 kB)
# Collecting nucliadb
#   Using cached nucliadb-2.17.0.post403-py3-none-any.whl (514 kB)
# Collecting nucliadb-utils[cache,fastapi,storages]==2.17.0-post403
#   Using cached nucliadb_utils-2.17.0.post403-py3-none-any.whl (96 kB)
# Collecting nucliadb-protos==2.17.0-post403
#   Using cached nucliadb_protos-2.17.0.post403-py3-none-any.whl (93 kB)
# Collecting nucliadb
#   Using cached nucliadb-2.17.0.post401-py3-none-any.whl (514 kB)
# Collecting nucliadb-utils[cache,fastapi,storages]==2.17.0-post401
#   Using cached nucliadb_utils-2.17.0.post401-py3-none-any.whl (96 kB)
# Collecting nucliadb-protos==2.17.0-post401
#   Using cached nucliadb_protos-2.17.0.post401-py3-none-any.whl (93 kB)
# Collecting nucliadb
#   Using cached nucliadb-2.16.0.post399-py3-none-any.whl (514 kB)
# Collecting nucliadb-utils[cache,fastapi,storages]==2.16.0-post399
#   Using cached nucliadb_utils-2.16.0.post399-py3-none-any.whl (95 kB)
# Collecting nucliadb-protos==2.16.0-post399
#   Using cached nucliadb_protos-2.16.0.post399-py3-none-any.whl (93 kB)
# Collecting nucliadb
#   Using cached nucliadb-2.16.0.post398-py3-none-any.whl (508 kB)
# Collecting nucliadb-utils[cache,fastapi,storages]==2.16.0-post398
#   Using cached nucliadb_utils-2.16.0.post398-py3-none-any.whl (95 kB)
# Collecting nucliadb-protos==2.16.0-post398
#   Using cached nucliadb_protos-2.16.0.post398-py3-none-any.whl (93 kB)
# Collecting nucliadb
#   Using cached nucliadb-2.16.0.post397-py3-none-any.whl (508 kB)
# Collecting nucliadb-utils[cache,fastapi,storages]==2.16.0-post397
#   Using cached nucliadb_utils-2.16.0.post397-py3-none-any.whl (95 kB)
# Collecting nucliadb-protos==2.16.0-post397
#   Using cached nucliadb_protos-2.16.0.post397-py3-none-any.whl (93 kB)
# Collecting nucliadb
#   Using cached nucliadb-2.16.0.post396-py3-none-any.whl (508 kB)
# Collecting nucliadb-utils[cache,fastapi,storages]==2.16.0-post396
#   Using cached nucliadb_utils-2.16.0.post396-py3-none-any.whl (95 kB)
# Collecting nucliadb-protos==2.16.0-post396
#   Using cached nucliadb_protos-2.16.0.post396-py3-none-any.whl (93 kB)
# Collecting nucliadb
#   Using cached nucliadb-2.16.0.post395-py3-none-any.whl (509 kB)
# Collecting nucliadb-utils[cache,fastapi,storages]==2.16.0-post395
#   Using cached nucliadb_utils-2.16.0.post395-py3-none-any.whl (95 kB)
# Collecting nucliadb-protos==2.16.0-post395
#   Using cached nucliadb_protos-2.16.0.post395-py3-none-any.whl (93 kB)
# Collecting nucliadb
#   Using cached nucliadb-2.16.0.post394-py3-none-any.whl (509 kB)
# Collecting nucliadb-utils[cache,fastapi,storages]==2.16.0-post394
#   Using cached nucliadb_utils-2.16.0.post394-py3-none-any.whl (95 kB)
# Collecting nucliadb-protos==2.16.0-post394
#   Using cached nucliadb_protos-2.16.0.post394-py3-none-any.whl (93 kB)
# Collecting nucliadb
#   Using cached nucliadb-2.16.0.post393-py3-none-any.whl (509 kB)
# Collecting nucliadb-utils[cache,fastapi,storages]==2.16.0-post393
#   Using cached nucliadb_utils-2.16.0.post393-py3-none-any.whl (95 kB)
# Collecting nucliadb-protos==2.16.0-post393
#   Using cached nucliadb_protos-2.16.0.post393-py3-none-any.whl (93 kB)
# Collecting nucliadb
#   Using cached nucliadb-2.16.0.post392-py3-none-any.whl (509 kB)
# Collecting nucliadb-utils[cache,fastapi,storages]==2.16.0-post392
#   Using cached nucliadb_utils-2.16.0.post392-py3-none-any.whl (95 kB)
# Collecting nucliadb-protos==2.16.0-post392
#   Using cached nucliadb_protos-2.16.0.post392-py3-none-any.whl (93 kB)
# Collecting nucliadb
#   Using cached nucliadb-2.16.0.post391-py3-none-any.whl (508 kB)
# Collecting nucliadb-utils[cache,fastapi,storages]==2.16.0-post391
#   Using cached nucliadb_utils-2.16.0.post391-py3-none-any.whl (95 kB)
# Collecting nucliadb-protos==2.16.0-post391
#   Using cached nucliadb_protos-2.16.0.post391-py3-none-any.whl (92 kB)
# Collecting nucliadb
#   Using cached nucliadb-2.16.0.post390-py3-none-any.whl (508 kB)
# Collecting nucliadb-utils[cache,fastapi,storages]==2.16.0-post390
#   Using cached nucliadb_utils-2.16.0.post390-py3-none-any.whl (95 kB)
# Collecting nucliadb-protos==2.16.0-post390
#   Using cached nucliadb_protos-2.16.0.post390-py3-none-any.whl (92 kB)
# Collecting nucliadb
#   Using cached nucliadb-2.16.0.post388-py3-none-any.whl (508 kB)
# Collecting nucliadb-utils[cache,fastapi,storages]==2.16.0-post388
#   Using cached nucliadb_utils-2.16.0.post388-py3-none-any.whl (95 kB)
# Collecting nucliadb-protos==2.16.0-post388
#   Using cached nucliadb_protos-2.16.0.post388-py3-none-any.whl (92 kB)
# Collecting nucliadb
#   Using cached nucliadb-2.16.0.post387-py3-none-any.whl (508 kB)
# Collecting nucliadb-utils[cache,fastapi,storages]==2.16.0-post387
#   Using cached nucliadb_utils-2.16.0.post387-py3-none-any.whl (95 kB)
# Collecting nucliadb-protos==2.16.0-post387
#   Using cached nucliadb_protos-2.16.0.post387-py3-none-any.whl (92 kB)
# Collecting nucliadb
#   Using cached nucliadb-2.16.0.post386-py3-none-any.whl (508 kB)
# Collecting nucliadb-utils[cache,fastapi,storages]==2.16.0-post386
#   Using cached nucliadb_utils-2.16.0.post386-py3-none-any.whl (95 kB)
# Collecting nucliadb-protos==2.16.0-post386
#   Using cached nucliadb_protos-2.16.0.post386-py3-none-any.whl (92 kB)
# Collecting nucliadb
#   Using cached nucliadb-2.16.0.post384-py3-none-any.whl (495 kB)
# Collecting nucliadb-utils[cache,fastapi,storages]==2.16.0-post384
#   Using cached nucliadb_utils-2.16.0.post384-py3-none-any.whl (94 kB)
# Collecting nucliadb-protos==2.16.0-post384
#   Using cached nucliadb_protos-2.16.0.post384-py3-none-any.whl (91 kB)
# Collecting nucliadb
#   Using cached nucliadb-2.16.0.post383-py3-none-any.whl (495 kB)
# Collecting nucliadb-utils[cache,fastapi,storages]==2.16.0-post383
#   Using cached nucliadb_utils-2.16.0.post383-py3-none-any.whl (94 kB)
# Collecting nucliadb-protos==2.16.0-post383
#   Using cached nucliadb_protos-2.16.0.post383-py3-none-any.whl (91 kB)
# Collecting nucliadb
#   Using cached nucliadb-2.16.0.post382-py3-none-any.whl (495 kB)
# Collecting nucliadb-utils[cache,fastapi,storages]==2.16.0-post382
#   Using cached nucliadb_utils-2.16.0.post382-py3-none-any.whl (94 kB)
# Collecting nucliadb-protos==2.16.0-post382
#   Using cached nucliadb_protos-2.16.0.post382-py3-none-any.whl (91 kB)
# Collecting nucliadb
#   Using cached nucliadb-2.16.0.post381-py3-none-any.whl (494 kB)
# Collecting nucliadb-utils[cache,fastapi,storages]==2.16.0-post381
#   Using cached nucliadb_utils-2.16.0.post381-py3-none-any.whl (94 kB)
# Collecting nucliadb-protos==2.16.0-post381
#   Using cached nucliadb_protos-2.16.0.post381-py3-none-any.whl (91 kB)
# Collecting nucliadb
#   Using cached nucliadb-2.16.0.post380-py3-none-any.whl (494 kB)
# Collecting nucliadb-utils[cache,fastapi,storages]==2.16.0-post380
#   Using cached nucliadb_utils-2.16.0.post380-py3-none-any.whl (94 kB)
# Collecting nucliadb-protos==2.16.0-post380
#   Using cached nucliadb_protos-2.16.0.post380-py3-none-any.whl (91 kB)
# Collecting nucliadb
#   Using cached nucliadb-2.16.0.post379-py3-none-any.whl (494 kB)
# Collecting nucliadb-utils[cache,fastapi,storages]==2.16.0-post379
#   Using cached nucliadb_utils-2.16.0.post379-py3-none-any.whl (94 kB)
# Collecting nucliadb-protos==2.16.0-post379
#   Using cached nucliadb_protos-2.16.0.post379-py3-none-any.whl (91 kB)
# Collecting nucliadb
#   Using cached nucliadb-2.16.0.post378-py3-none-any.whl (494 kB)
# Collecting nucliadb-utils[cache,fastapi,storages]==2.16.0-post378
#   Using cached nucliadb_utils-2.16.0.post378-py3-none-any.whl (94 kB)
# Collecting nucliadb-protos==2.16.0-post378
#   Using cached nucliadb_protos-2.16.0.post378-py3-none-any.whl (91 kB)
# Collecting nucliadb
#   Using cached nucliadb-2.16.0.post377-py3-none-any.whl (494 kB)
# Collecting nucliadb-utils[cache,fastapi,storages]==2.16.0-post377
#   Using cached nucliadb_utils-2.16.0.post377-py3-none-any.whl (94 kB)
# Collecting nucliadb-protos==2.16.0-post377
#   Using cached nucliadb_protos-2.16.0.post377-py3-none-any.whl (91 kB)
# Collecting nucliadb
#   Using cached nucliadb-2.16.0.post376-py3-none-any.whl (494 kB)
# Collecting nucliadb-utils[cache,fastapi,storages]==2.16.0-post376
#   Using cached nucliadb_utils-2.16.0.post376-py3-none-any.whl (94 kB)
# Collecting nucliadb-protos==2.16.0-post376
#   Using cached nucliadb_protos-2.16.0.post376-py3-none-any.whl (91 kB)
# Collecting nucliadb
#   Using cached nucliadb-2.16.0.post375-py3-none-any.whl (494 kB)
# Collecting nucliadb-utils[cache,fastapi,storages]==2.16.0-post375
#   Using cached nucliadb_utils-2.16.0.post375-py3-none-any.whl (94 kB)
# Collecting nucliadb-protos==2.16.0-post375
#   Using cached nucliadb_protos-2.16.0.post375-py3-none-any.whl (91 kB)
# Collecting nucliadb
#   Using cached nucliadb-2.16.0.post374-py3-none-any.whl (494 kB)
# Collecting nucliadb-utils[cache,fastapi,storages]==2.16.0-post374
#   Using cached nucliadb_utils-2.16.0.post374-py3-none-any.whl (94 kB)
# Collecting nucliadb-protos==2.16.0-post374
#   Using cached nucliadb_protos-2.16.0.post374-py3-none-any.whl (91 kB)
# Collecting nucliadb
#   Using cached nucliadb-2.16.0.post373-py3-none-any.whl (494 kB)
# Collecting nucliadb-utils[cache,fastapi,storages]==2.16.0-post373
#   Using cached nucliadb_utils-2.16.0.post373-py3-none-any.whl (94 kB)
# Collecting nucliadb-protos==2.16.0-post373
#   Using cached nucliadb_protos-2.16.0.post373-py3-none-any.whl (91 kB)
# Collecting nucliadb
#   Using cached nucliadb-2.16.0.post372-py3-none-any.whl (489 kB)
# Collecting nucliadb-utils[cache,fastapi,storages]==2.16.0-post372
#   Using cached nucliadb_utils-2.16.0.post372-py3-none-any.whl (94 kB)
# Collecting nucliadb-protos==2.16.0-post372
#   Using cached nucliadb_protos-2.16.0.post372-py3-none-any.whl (91 kB)
# Collecting nucliadb
#   Using cached nucliadb-2.16.0.post371-py3-none-any.whl (489 kB)
# Collecting nucliadb-utils[cache,fastapi,storages]==2.16.0-post371
#   Using cached nucliadb_utils-2.16.0.post371-py3-none-any.whl (94 kB)
# Collecting nucliadb-protos==2.16.0-post371
#   Using cached nucliadb_protos-2.16.0.post371-py3-none-any.whl (91 kB)
# Collecting nucliadb
#   Using cached nucliadb-2.16.0.post370-py3-none-any.whl (489 kB)
# Collecting nucliadb-utils[cache,fastapi,storages]==2.16.0-post370
#   Using cached nucliadb_utils-2.16.0.post370-py3-none-any.whl (94 kB)
# Collecting nucliadb-protos==2.16.0-post370
#   Using cached nucliadb_protos-2.16.0.post370-py3-none-any.whl (91 kB)
# Collecting nucliadb
#   Using cached nucliadb-2.16.0.post369-py3-none-any.whl (489 kB)
# Collecting nucliadb-utils[cache,fastapi,storages]==2.16.0-post369
#   Using cached nucliadb_utils-2.16.0.post369-py3-none-any.whl (94 kB)
# Collecting nucliadb-protos==2.16.0-post369
#   Using cached nucliadb_protos-2.16.0.post369-py3-none-any.whl (91 kB)
# Collecting nucliadb
#   Using cached nucliadb-2.16.0.post368-py3-none-any.whl (489 kB)
# Collecting nucliadb-utils[cache,fastapi,storages]==2.16.0-post368
#   Using cached nucliadb_utils-2.16.0.post368-py3-none-any.whl (94 kB)
# Collecting nucliadb-protos==2.16.0-post368
#   Using cached nucliadb_protos-2.16.0.post368-py3-none-any.whl (91 kB)
# Collecting nucliadb
#   Using cached nucliadb-2.16.0.post367-py3-none-any.whl (489 kB)
# Collecting nucliadb-utils[cache,fastapi,storages]==2.16.0-post367
#   Using cached nucliadb_utils-2.16.0.post367-py3-none-any.whl (94 kB)
# Collecting nucliadb-protos==2.16.0-post367
#   Using cached nucliadb_protos-2.16.0.post367-py3-none-any.whl (91 kB)
# Collecting nucliadb
#   Using cached nucliadb-2.16.0.post366-py3-none-any.whl (489 kB)
# Collecting nucliadb-utils[cache,fastapi,storages]==2.16.0-post366
#   Using cached nucliadb_utils-2.16.0.post366-py3-none-any.whl (94 kB)
# Collecting nucliadb-protos==2.16.0-post366
#   Using cached nucliadb_protos-2.16.0.post366-py3-none-any.whl (91 kB)
# Collecting nucliadb
#   Using cached nucliadb-2.16.0.post364-py3-none-any.whl (489 kB)
# Collecting nucliadb-utils[cache,fastapi,storages]==2.16.0-post364
#   Using cached nucliadb_utils-2.16.0.post364-py3-none-any.whl (94 kB)
# Collecting nucliadb-protos==2.16.0-post364
#   Using cached nucliadb_protos-2.16.0.post364-py3-none-any.whl (91 kB)
# Collecting nucliadb
#   Using cached nucliadb-2.16.0.post363-py3-none-any.whl (489 kB)
# Collecting nucliadb-utils[cache,fastapi,storages]==2.16.0-post363
#   Using cached nucliadb_utils-2.16.0.post363-py3-none-any.whl (94 kB)
# Collecting nucliadb-protos==2.16.0-post363
#   Using cached nucliadb_protos-2.16.0.post363-py3-none-any.whl (90 kB)
# Collecting nucliadb
#   Using cached nucliadb-2.16.0.post361-py3-none-any.whl (454 kB)
# Collecting nucliadb-utils[cache,fastapi,storages]==2.16.0-post361
#   Using cached nucliadb_utils-2.16.0.post361-py3-none-any.whl (94 kB)
# Collecting nucliadb-protos==2.16.0-post361
#   Using cached nucliadb_protos-2.16.0.post361-py3-none-any.whl (91 kB)
# Collecting nucliadb
#   Using cached nucliadb-2.15.2.post360-py3-none-any.whl (454 kB)
# Collecting nucliadb-utils[cache,fastapi,storages]==2.15.2-post360
#   Using cached nucliadb_utils-2.15.2.post360-py3-none-any.whl (94 kB)
# Collecting nucliadb-protos==2.15.2-post360
#   Using cached nucliadb_protos-2.15.2.post360-py3-none-any.whl (91 kB)
# Collecting nucliadb
#   Using cached nucliadb-2.15.2.post359-py3-none-any.whl (454 kB)
# Collecting nucliadb-utils[cache,fastapi,storages]==2.15.2-post359
#   Using cached nucliadb_utils-2.15.2.post359-py3-none-any.whl (94 kB)
# Collecting nucliadb-protos==2.15.2-post359
#   Using cached nucliadb_protos-2.15.2.post359-py3-none-any.whl (90 kB)
# Collecting nucliadb
#   Using cached nucliadb-2.15.2.post358-py3-none-any.whl (454 kB)
# Collecting nucliadb-utils[cache,fastapi,storages]==2.15.2-post358
#   Using cached nucliadb_utils-2.15.2.post358-py3-none-any.whl (94 kB)
# Collecting nucliadb-protos==2.15.2-post358
#   Using cached nucliadb_protos-2.15.2.post358-py3-none-any.whl (91 kB)
# Collecting nucliadb
#   Using cached nucliadb-2.15.2.post357-py3-none-any.whl (452 kB)
# Collecting nucliadb-utils[cache,fastapi,storages]==2.15.2-post357
#   Using cached nucliadb_utils-2.15.2.post357-py3-none-any.whl (94 kB)
# Collecting nucliadb-protos==2.15.2-post357
#   Using cached nucliadb_protos-2.15.2.post357-py3-none-any.whl (91 kB)
# Collecting nucliadb
#   Using cached nucliadb-2.15.2.post356-py3-none-any.whl (452 kB)
# Collecting nucliadb-utils[cache,fastapi,storages]==2.15.2-post356
#   Using cached nucliadb_utils-2.15.2.post356-py3-none-any.whl (94 kB)
# Collecting nucliadb-protos==2.15.2-post356
#   Using cached nucliadb_protos-2.15.2.post356-py3-none-any.whl (90 kB)
# Collecting nucliadb
#   Using cached nucliadb-2.15.2.post355-py3-none-any.whl (452 kB)
# Collecting nucliadb-utils[cache,fastapi,storages]==2.15.2-post355
#   Using cached nucliadb_utils-2.15.2.post355-py3-none-any.whl (94 kB)
# Collecting nucliadb-protos==2.15.2-post355
#   Using cached nucliadb_protos-2.15.2.post355-py3-none-any.whl (91 kB)
# Collecting nucliadb
#   Using cached nucliadb-2.15.2.post354-py3-none-any.whl (452 kB)
# Collecting nucliadb-utils[cache,fastapi,storages]==2.15.2-post354
#   Using cached nucliadb_utils-2.15.2.post354-py3-none-any.whl (94 kB)
# Collecting nucliadb-protos==2.15.2-post354
#   Using cached nucliadb_protos-2.15.2.post354-py3-none-any.whl (90 kB)
# Collecting nucliadb
#   Using cached nucliadb-2.15.1.post353-py3-none-any.whl (452 kB)
# Collecting nucliadb-utils[cache,fastapi,storages]==2.15.1-post353
#   Using cached nucliadb_utils-2.15.1.post353-py3-none-any.whl (94 kB)
# Collecting nucliadb-protos==2.15.1-post353
#   Using cached nucliadb_protos-2.15.1.post353-py3-none-any.whl (90 kB)
# Collecting nucliadb-models==2.15.1-post353
#   Using cached nucliadb_models-2.15.1.post353-py3-none-any.whl (35 kB)
# Collecting nucliadb
#   Using cached nucliadb-2.15.0.post352-py3-none-any.whl (452 kB)
# Collecting nucliadb-utils[cache,fastapi,storages]==2.15.0-post352
#   Using cached nucliadb_utils-2.15.0.post352-py3-none-any.whl (94 kB)
# Collecting nucliadb-protos==2.15.0-post352
#   Using cached nucliadb_protos-2.15.0.post352-py3-none-any.whl (91 kB)
# Collecting nucliadb-models==2.15.0-post352
#   Using cached nucliadb_models-2.15.0.post352-py3-none-any.whl (35 kB)
# Collecting nucliadb
#   Using cached nucliadb-2.15.0.post351-py3-none-any.whl (452 kB)
# Collecting nucliadb-utils[cache,fastapi,storages]==2.15.0-post351
#   Using cached nucliadb_utils-2.15.0.post351-py3-none-any.whl (94 kB)
# Collecting nucliadb-protos==2.15.0-post351
#   Using cached nucliadb_protos-2.15.0.post351-py3-none-any.whl (91 kB)
# Collecting nucliadb-models==2.15.0-post351
#   Using cached nucliadb_models-2.15.0.post351-py3-none-any.whl (35 kB)
# Collecting nucliadb
#   Using cached nucliadb-2.15.0.post350-py3-none-any.whl (452 kB)
# Collecting nucliadb-utils[cache,fastapi,storages]==2.15.0-post350
#   Using cached nucliadb_utils-2.15.0.post350-py3-none-any.whl (94 kB)
# Collecting nucliadb-protos==2.15.0-post350
#   Using cached nucliadb_protos-2.15.0.post350-py3-none-any.whl (90 kB)
# Collecting nucliadb-models==2.15.0-post350
#   Using cached nucliadb_models-2.15.0.post350-py3-none-any.whl (35 kB)
# Collecting nucliadb
#   Using cached nucliadb-2.15.0.post349-py3-none-any.whl (452 kB)
# Collecting nucliadb-utils[cache,fastapi,storages]==2.15.0-post349
#   Using cached nucliadb_utils-2.15.0.post349-py3-none-any.whl (94 kB)
# Collecting nucliadb-protos==2.15.0-post349
#   Using cached nucliadb_protos-2.15.0.post349-py3-none-any.whl (90 kB)
# Collecting nucliadb-models==2.15.0-post349
#   Using cached nucliadb_models-2.15.0.post349-py3-none-any.whl (35 kB)
# Collecting nucliadb
#   Using cached nucliadb-2.15.0.post348-py3-none-any.whl (452 kB)
# Collecting nucliadb-utils[cache,fastapi,storages]==2.15.0-post348
#   Using cached nucliadb_utils-2.15.0.post348-py3-none-any.whl (94 kB)
# Collecting nucliadb-protos==2.15.0-post348
#   Using cached nucliadb_protos-2.15.0.post348-py3-none-any.whl (90 kB)
# Collecting nucliadb-models==2.15.0-post348
#   Using cached nucliadb_models-2.15.0.post348-py3-none-any.whl (35 kB)
# Collecting nucliadb
#   Using cached nucliadb-2.15.0.post347-py3-none-any.whl (452 kB)
# Collecting nucliadb-utils[cache,fastapi,storages]==2.15.0-post347
#   Using cached nucliadb_utils-2.15.0.post347-py3-none-any.whl (94 kB)
# Collecting nucliadb-protos==2.15.0-post347
#   Using cached nucliadb_protos-2.15.0.post347-py3-none-any.whl (90 kB)
# Collecting nucliadb-models==2.15.0-post347
#   Using cached nucliadb_models-2.15.0.post347-py3-none-any.whl (35 kB)
# Collecting nucliadb
#   Using cached nucliadb-2.15.0.post346-py3-none-any.whl (452 kB)
# Collecting nucliadb-utils[cache,fastapi,storages]==2.15.0-post346
#   Using cached nucliadb_utils-2.15.0.post346-py3-none-any.whl (94 kB)
# Collecting nucliadb-protos==2.15.0-post346
#   Using cached nucliadb_protos-2.15.0.post346-py3-none-any.whl (90 kB)
# Collecting nucliadb-models==2.15.0-post346
#   Using cached nucliadb_models-2.15.0.post346-py3-none-any.whl (35 kB)
# Collecting nucliadb
#   Using cached nucliadb-2.15.0.post345-py3-none-any.whl (452 kB)
# Collecting nucliadb-utils[cache,fastapi,storages]==2.15.0-post345
#   Using cached nucliadb_utils-2.15.0.post345-py3-none-any.whl (94 kB)
# Collecting nucliadb-protos==2.15.0-post345
#   Using cached nucliadb_protos-2.15.0.post345-py3-none-any.whl (90 kB)
# Collecting nucliadb-models==2.15.0-post345
#   Using cached nucliadb_models-2.15.0.post345-py3-none-any.whl (35 kB)
# Collecting nucliadb
#   Using cached nucliadb-2.15.0.post344-py3-none-any.whl (452 kB)
# Collecting nucliadb-utils[cache,fastapi,storages]==2.15.0-post344
#   Using cached nucliadb_utils-2.15.0.post344-py3-none-any.whl (94 kB)
# Collecting nucliadb-protos==2.15.0-post344
#   Using cached nucliadb_protos-2.15.0.post344-py3-none-any.whl (90 kB)
# Collecting nucliadb-models==2.15.0-post344
#   Using cached nucliadb_models-2.15.0.post344-py3-none-any.whl (35 kB)
# Collecting nucliadb
#   Using cached nucliadb-2.15.0.post343-py3-none-any.whl (452 kB)
# Collecting nucliadb-utils[cache,fastapi,storages]==2.15.0-post343
#   Using cached nucliadb_utils-2.15.0.post343-py3-none-any.whl (94 kB)
# Collecting nucliadb-protos==2.15.0-post343
#   Using cached nucliadb_protos-2.15.0.post343-py3-none-any.whl (90 kB)
# Collecting nucliadb-models==2.15.0-post343
#   Using cached nucliadb_models-2.15.0.post343-py3-none-any.whl (35 kB)
# Collecting nucliadb
#   Using cached nucliadb-2.15.0.post342-py3-none-any.whl (452 kB)
# Collecting nucliadb-utils[cache,fastapi,storages]==2.15.0-post342
#   Using cached nucliadb_utils-2.15.0.post342-py3-none-any.whl (94 kB)
# Collecting nucliadb-protos==2.15.0-post342
#   Using cached nucliadb_protos-2.15.0.post342-py3-none-any.whl (90 kB)
# Collecting nucliadb-models==2.15.0-post342
#   Using cached nucliadb_models-2.15.0.post342-py3-none-any.whl (35 kB)
# Collecting nucliadb
#   Using cached nucliadb-2.15.0.post341-py3-none-any.whl (452 kB)
# Collecting nucliadb-utils[cache,fastapi,storages]==2.15.0-post341
#   Using cached nucliadb_utils-2.15.0.post341-py3-none-any.whl (94 kB)
# Collecting nucliadb-protos==2.15.0-post341
#   Using cached nucliadb_protos-2.15.0.post341-py3-none-any.whl (90 kB)
# Collecting nucliadb-models==2.15.0-post341
#   Using cached nucliadb_models-2.15.0.post341-py3-none-any.whl (35 kB)
# Collecting nucliadb
#   Using cached nucliadb-2.15.0.post340-py3-none-any.whl (452 kB)
# Collecting nucliadb-utils[cache,fastapi,storages]==2.15.0-post340
#   Using cached nucliadb_utils-2.15.0.post340-py3-none-any.whl (94 kB)
# Collecting nucliadb-protos==2.15.0-post340
#   Using cached nucliadb_protos-2.15.0.post340-py3-none-any.whl (90 kB)
# Collecting nucliadb-models==2.15.0-post340
#   Using cached nucliadb_models-2.15.0.post340-py3-none-any.whl (35 kB)
# Collecting nucliadb
#   Using cached nucliadb-2.14.0.post339-py3-none-any.whl (452 kB)
# Collecting nucliadb-utils[cache,fastapi,storages]==2.14.0-post339
#   Using cached nucliadb_utils-2.14.0.post339-py3-none-any.whl (94 kB)
# Collecting nucliadb-protos==2.14.0-post339
#   Using cached nucliadb_protos-2.14.0.post339-py3-none-any.whl (90 kB)
# Collecting nucliadb-models==2.14.0-post339
#   Using cached nucliadb_models-2.14.0.post339-py3-none-any.whl (35 kB)
# Collecting nucliadb
#   Using cached nucliadb-2.14.0.post337-py3-none-any.whl (486 kB)
# Collecting nucliadb-utils[cache,fastapi,storages]==2.14.0-post337
#   Using cached nucliadb_utils-2.14.0.post337-py3-none-any.whl (94 kB)
# Collecting nucliadb-protos==2.14.0-post337
#   Using cached nucliadb_protos-2.14.0.post337-py3-none-any.whl (90 kB)
# Collecting nucliadb-models==2.14.0-post337
#   Using cached nucliadb_models-2.14.0.post337-py3-none-any.whl (35 kB)
# Collecting nucliadb
#   Using cached nucliadb-2.14.0.post336-py3-none-any.whl (486 kB)
# Collecting nucliadb-utils[cache,fastapi,storages]==2.14.0-post336
#   Using cached nucliadb_utils-2.14.0.post336-py3-none-any.whl (94 kB)
# Collecting nucliadb-protos==2.14.0-post336
#   Using cached nucliadb_protos-2.14.0.post336-py3-none-any.whl (90 kB)
# Collecting nucliadb-models==2.14.0-post336
#   Using cached nucliadb_models-2.14.0.post336-py3-none-any.whl (35 kB)
# Collecting nucliadb
#   Using cached nucliadb-2.13.0.post335-py3-none-any.whl (486 kB)
# Collecting nucliadb-utils[cache,fastapi,storages]==2.13.0-post335
#   Using cached nucliadb_utils-2.13.0.post335-py3-none-any.whl (94 kB)
# Collecting nucliadb-protos==2.13.0-post335
#   Using cached nucliadb_protos-2.13.0.post335-py3-none-any.whl (90 kB)
# Collecting nucliadb-models==2.13.0-post335
#   Using cached nucliadb_models-2.13.0.post335-py3-none-any.whl (35 kB)
# Collecting nucliadb
#   Using cached nucliadb-2.13.0.post334-py3-none-any.whl (486 kB)
# Collecting nucliadb-utils[cache,fastapi,storages]==2.13.0-post334
#   Using cached nucliadb_utils-2.13.0.post334-py3-none-any.whl (94 kB)
# Collecting nucliadb-protos==2.13.0-post334
#   Using cached nucliadb_protos-2.13.0.post334-py3-none-any.whl (90 kB)
# Collecting nucliadb-models==2.13.0-post334
#   Using cached nucliadb_models-2.13.0.post334-py3-none-any.whl (34 kB)
# Collecting nucliadb
#   Using cached nucliadb-2.13.0.post333-py3-none-any.whl (486 kB)
# Collecting nucliadb-utils[cache,fastapi,storages]==2.13.0-post333
#   Using cached nucliadb_utils-2.13.0.post333-py3-none-any.whl (94 kB)
# Collecting nucliadb-protos==2.13.0-post333
#   Using cached nucliadb_protos-2.13.0.post333-py3-none-any.whl (90 kB)
# Collecting nucliadb-models==2.13.0-post333
#   Using cached nucliadb_models-2.13.0.post333-py3-none-any.whl (34 kB)
# Collecting nucliadb
#   Using cached nucliadb-2.13.0.post331-py3-none-any.whl (483 kB)
# Collecting nucliadb-utils[cache,fastapi,storages]==2.13.0-post331
#   Using cached nucliadb_utils-2.13.0.post331-py3-none-any.whl (94 kB)
# Collecting nucliadb-protos==2.13.0-post331
#   Using cached nucliadb_protos-2.13.0.post331-py3-none-any.whl (90 kB)
# Collecting nucliadb-models==2.13.0-post331
#   Using cached nucliadb_models-2.13.0.post331-py3-none-any.whl (34 kB)
# Collecting nucliadb
#   Using cached nucliadb-2.13.0.post330-py3-none-any.whl (483 kB)
# Collecting nucliadb-utils[cache,fastapi,storages]==2.13.0-post330
#   Using cached nucliadb_utils-2.13.0.post330-py3-none-any.whl (94 kB)
# Collecting nucliadb-protos==2.13.0-post330
#   Using cached nucliadb_protos-2.13.0.post330-py3-none-any.whl (90 kB)
# Collecting nucliadb-models==2.13.0-post330
#   Using cached nucliadb_models-2.13.0.post330-py3-none-any.whl (34 kB)
# Collecting nucliadb
#   Using cached nucliadb-2.13.0.post329-py3-none-any.whl (483 kB)
# Collecting nucliadb-utils[cache,fastapi,storages]==2.13.0-post329
#   Using cached nucliadb_utils-2.13.0.post329-py3-none-any.whl (94 kB)
# Collecting nucliadb-protos==2.13.0-post329
#   Using cached nucliadb_protos-2.13.0.post329-py3-none-any.whl (90 kB)
# Collecting nucliadb-models==2.13.0-post329
#   Using cached nucliadb_models-2.13.0.post329-py3-none-any.whl (34 kB)
# Collecting nucliadb
#   Using cached nucliadb-2.13.0.post327-py3-none-any.whl (483 kB)
# Collecting nucliadb-utils[cache,fastapi,storages]==2.13.0-post327
#   Using cached nucliadb_utils-2.13.0.post327-py3-none-any.whl (94 kB)
# Collecting nucliadb-protos==2.13.0-post327
#   Using cached nucliadb_protos-2.13.0.post327-py3-none-any.whl (90 kB)
# Collecting nucliadb-models==2.13.0-post327
#   Using cached nucliadb_models-2.13.0.post327-py3-none-any.whl (34 kB)
# Collecting nucliadb
#   Using cached nucliadb-2.13.0.post326-py3-none-any.whl (483 kB)
# Collecting nucliadb-utils[cache,fastapi,storages]==2.13.0-post326
#   Using cached nucliadb_utils-2.13.0.post326-py3-none-any.whl (94 kB)
# Collecting nucliadb-protos==2.13.0-post326
#   Using cached nucliadb_protos-2.13.0.post326-py3-none-any.whl (90 kB)
# Collecting nucliadb-models==2.13.0-post326
#   Using cached nucliadb_models-2.13.0.post326-py3-none-any.whl (34 kB)
# Collecting nucliadb
#   Using cached nucliadb-2.13.0.post325-py3-none-any.whl (483 kB)
# Collecting nucliadb-utils[cache,fastapi,storages]==2.13.0-post325
#   Using cached nucliadb_utils-2.13.0.post325-py3-none-any.whl (94 kB)
# Collecting nucliadb-protos==2.13.0-post325
#   Using cached nucliadb_protos-2.13.0.post325-py3-none-any.whl (90 kB)
# Collecting nucliadb-models==2.13.0-post325
#   Using cached nucliadb_models-2.13.0.post325-py3-none-any.whl (34 kB)
# Collecting nucliadb
#   Using cached nucliadb-2.13.0.post323-py3-none-any.whl (482 kB)
# Collecting nucliadb-utils[cache,fastapi,storages]==2.13.0-post323
#   Using cached nucliadb_utils-2.13.0.post323-py3-none-any.whl (94 kB)
# Collecting nucliadb-protos==2.13.0-post323
#   Using cached nucliadb_protos-2.13.0.post323-py3-none-any.whl (90 kB)
# Collecting nucliadb-models==2.13.0-post323
#   Using cached nucliadb_models-2.13.0.post323-py3-none-any.whl (34 kB)
# Collecting nucliadb
# ...
#     nucliadb 2.13.0.post321 depends on tikv-client>=0.0.3
#     nucliadb 2.13.0.post320 depends on tikv-client>=0.0.3
#     nucliadb 2.13.0.post311 depends on tikv-client>=0.0.3
#     nucliadb 2.13.0.post310 depends on tikv-client>=0.0.3
#     nucliadb 2.13.0.post309 depends on tikv-client>=0.0.3
#     nucliadb 2.13.0.post308 depends on tikv-client>=0.0.3
#     nucliadb 2.13.0.post307 depends on tikv-client>=0.0.3
#     nucliadb 2.13.0.post306 depends on tikv-client>=0.0.3
#     nucliadb 2.13.0.post305 depends on tikv-client>=0.0.3
#     nucliadb 2.13.0.post304 depends on tikv-client>=0.0.3
#     nucliadb 2.13.0.post303 depends on tikv-client>=0.0.3
#     nucliadb 2.13.0.post302 depends on tikv-client>=0.0.3
#     nucliadb 2.13.0.post301 depends on tikv-client>=0.0.3
#     nucliadb 2.13.0.post300 depends on tikv-client>=0.0.3
#     nucliadb 2.13.0.post298 depends on tikv-client>=0.0.3
#     nucliadb 2.13.0.post297 depends on tikv-client>=0.0.3
#     nucliadb 2.13.0.post296 depends on tikv-client>=0.0.3
#     nucliadb 2.13.0.post295 depends on tikv-client>=0.0.3
#     nucliadb 2.13.0.post294 depends on tikv-client>=0.0.3
#     nucliadb 2.13.0.post293 depends on tikv-client>=0.0.3
#     nucliadb 2.13.0.post292 depends on tikv-client>=0.0.3
#     nucliadb 2.13.0.post291 depends on tikv-client>=0.0.3
#     nucliadb 2.13.0.post290 depends on tikv-client>=0.0.3
#     nucliadb 2.13.0.post289 depends on tikv-client>=0.0.3
#     nucliadb 2.12.0.post288 depends on tikv-client>=0.0.3
#     nucliadb 2.12.0.post287 depends on tikv-client>=0.0.3
#     nucliadb 2.11.0.post286 depends on tikv-client>=0.0.3
#     nucliadb 2.11.0.post285 depends on tikv-client>=0.0.3
#     nucliadb 2.11.0.post284 depends on tikv-client>=0.0.3
#     nucliadb 2.11.0.post282 depends on tikv-client>=0.0.3
#     nucliadb 2.11.0.post281 depends on tikv-client>=0.0.3
#     nucliadb 2.11.0.post280 depends on tikv-client>=0.0.3
#     nucliadb 2.11.0.post279 depends on tikv-client>=0.0.3
#     nucliadb 2.11.0.post278 depends on tikv-client>=0.0.3
#     nucliadb 2.11.0.post277 depends on tikv-client>=0.0.3
#     nucliadb 2.11.0.post276 depends on tikv-client>=0.0.3
#     nucliadb 2.11.0.post275 depends on tikv-client>=0.0.3
#     nucliadb 2.11.0.post274 depends on tikv-client>=0.0.3
#     nucliadb 2.11.0.post273 depends on tikv-client>=0.0.3
#     nucliadb 2.10.0.post272 depends on tikv-client>=0.0.3
#     nucliadb 2.10.0.post271 depends on tikv-client>=0.0.3
#     nucliadb 2.10.0.post270 depends on tikv-client>=0.0.3
#     nucliadb 2.10.0.post269 depends on tikv-client>=0.0.3
#     nucliadb 2.10.0.post268 depends on tikv-client>=0.0.3
#     nucliadb 2.9.0.post267 depends on tikv-client>=0.0.3
#     nucliadb 2.9.0.post266 depends on tikv-client>=0.0.3
#     nucliadb 2.9.0.post265 depends on nucliadb-utils[cache, fastapi and storages]==2.9.0-post265
#     nucliadb 2.9.0.post263 depends on tikv-client>=0.0.3
#     nucliadb 2.9.0.post262 depends on tikv-client>=0.0.3
#     nucliadb 2.9.0.post261 depends on tikv-client>=0.0.3
#     nucliadb 2.9.0.post259 depends on tikv-client>=0.0.3
#     nucliadb 2.9.0.post258 depends on tikv-client>=0.0.3
#     nucliadb 2.8.5.post257 depends on tikv-client>=0.0.3
#     nucliadb 2.8.5.post256 depends on tikv-client>=0.0.3
#     nucliadb 2.8.5.post255 depends on tikv-client>=0.0.3
#     nucliadb 2.8.5.post254 depends on tikv-client>=0.0.3
#     nucliadb 2.8.5.post253 depends on tikv-client>=0.0.3
#     nucliadb 2.8.5.post252 depends on tikv-client>=0.0.3
#     nucliadb 2.8.5.post249 depends on tikv-client>=0.0.3
#     nucliadb 2.8.5.post247 depends on tikv-client>=0.0.3
#     nucliadb 2.8.5.post246 depends on tikv-client>=0.0.3
#     nucliadb 2.8.5.post245 depends on tikv-client>=0.0.3
#     nucliadb 2.8.5.post244 depends on tikv-client>=0.0.3
#     nucliadb 2.8.5.post243 depends on tikv-client>=0.0.3
#     nucliadb 2.8.5.post242 depends on tikv-client>=0.0.3
#     nucliadb 2.8.5.post241 depends on tikv-client>=0.0.3
#     nucliadb 2.8.5.post240 depends on tikv-client>=0.0.3
#     nucliadb 2.8.5.post239 depends on tikv-client>=0.0.3
#     nucliadb 2.8.5.post238 depends on tikv-client>=0.0.3
#     nucliadb 2.8.5.post237 depends on tikv-client>=0.0.3
#     nucliadb 2.8.5.post236 depends on tikv-client>=0.0.3
#     nucliadb 2.8.5.post235 depends on tikv-client>=0.0.3
#     nucliadb 2.8.4.post234 depends on tikv-client>=0.0.3
#     nucliadb 2.8.4.post233 depends on tikv-client>=0.0.3
#     nucliadb 2.8.4.post232 depends on tikv-client>=0.0.3
#     nucliadb 2.8.4.post231 depends on tikv-client>=0.0.3
#     nucliadb 2.8.4.post230 depends on tikv-client>=0.0.3
#     nucliadb 2.8.3.post229 depends on tikv-client>=0.0.3
#     nucliadb 2.8.3.post228 depends on tikv-client>=0.0.3
#     nucliadb 2.8.2.post226 depends on tikv-client>=0.0.3
#     nucliadb 2.8.2.post221 depends on tikv-client>=0.0.3
#     nucliadb 2.8.2.post220 depends on tikv-client>=0.0.3
#     nucliadb 2.8.2.post219 depends on tikv-client>=0.0.3
#     nucliadb 2.8.2.post218 depends on tikv-client>=0.0.3
#     nucliadb 2.8.1.post217 depends on tikv-client>=0.0.3
#     nucliadb 2.8.0.post216 depends on tikv-client>=0.0.3
#     nucliadb 2.8.0.post215 depends on tikv-client>=0.0.3
#     nucliadb 2.7.0.post214 depends on tikv-client>=0.0.3
#     nucliadb 2.7.0.post213 depends on tikv-client>=0.0.3
#     nucliadb 2.7.0.post212 depends on tikv-client>=0.0.3
#     nucliadb 2.7.0.post211 depends on tikv-client>=0.0.3
#     nucliadb 2.7.0.post210 depends on tikv-client>=0.0.3
#     nucliadb 2.7.0.post209 depends on tikv-client>=0.0.3
#     nucliadb 2.7.0.post208 depends on tikv-client>=0.0.3
#     nucliadb 2.7.0.post207 depends on tikv-client>=0.0.3
#     nucliadb 2.7.0.post206 depends on tikv-client>=0.0.3
#     nucliadb 2.7.0.post205 depends on tikv-client>=0.0.3
#     nucliadb 2.7.0.post204 depends on tikv-client>=0.0.3
#     nucliadb 2.7.0.post203 depends on tikv-client>=0.0.3
#     nucliadb 2.7.0.post202 depends on tikv-client>=0.0.3
#     nucliadb 2.7.0.post201 depends on tikv-client>=0.0.3
#     nucliadb 2.7.0.post200 depends on tikv-client>=0.0.3
#     nucliadb 2.7.0.post199 depends on tikv-client>=0.0.3
#     nucliadb 2.7.0.post198 depends on tikv-client>=0.0.3
#     nucliadb 2.7.0.post197 depends on tikv-client>=0.0.3
#     nucliadb 2.7.0.post196 depends on tikv-client>=0.0.3
#     nucliadb 2.7.0.post195 depends on tikv-client>=0.0.3
#     nucliadb 2.7.0.post194 depends on tikv-client>=0.0.3
#     nucliadb 2.7.0.post193 depends on tikv-client>=0.0.3
#     nucliadb 2.7.0.post192 depends on tikv-client>=0.0.3
#     nucliadb 2.7.0.post189 depends on tikv-client>=0.0.3
#     nucliadb 2.7.0.post188 depends on tikv-client>=0.0.3
#     nucliadb 2.7.0.post187 depends on tikv-client>=0.0.3
#     nucliadb 2.7.0.post186 depends on tikv-client>=0.0.3
#     nucliadb 2.7.0.post185 depends on tikv-client>=0.0.3
#     nucliadb 2.7.0.post183 depends on tikv-client>=0.0.3
#     nucliadb 2.7.0.post182 depends on tikv-client>=0.0.3
#     nucliadb 2.7.0.post181 depends on tikv-client>=0.0.3
#     nucliadb 2.7.0.post180 depends on tikv-client>=0.0.3
#     nucliadb 2.7.0.post179 depends on tikv-client>=0.0.3
#     nucliadb 2.7.0.post178 depends on tikv-client>=0.0.3
#     nucliadb 2.7.0.post177 depends on tikv-client>=0.0.3
#     nucliadb 2.7.0.post176 depends on tikv-client>=0.0.3
#     nucliadb 2.7.0.post175 depends on tikv-client>=0.0.3
#     nucliadb 2.7.0.post174 depends on tikv-client>=0.0.3
#     nucliadb 2.7.0.post173 depends on tikv-client>=0.0.3
#     nucliadb 2.7.0.post172 depends on tikv-client>=0.0.3
#     nucliadb 2.7.0.post171 depends on tikv-client>=0.0.3
#     nucliadb 2.7.0.post170 depends on tikv-client>=0.0.3
#     nucliadb 2.7.0.post169 depends on tikv-client>=0.0.3
#     nucliadb 2.7.0.post168 depends on tikv-client>=0.0.3
#     nucliadb 2.7.0.post167 depends on tikv-client>=0.0.3
#     nucliadb 2.7.0.post166 depends on tikv-client>=0.0.3
#     nucliadb 2.7.0.post165 depends on tikv-client>=0.0.3
#     nucliadb 2.7.0.post162 depends on tikv-client>=0.0.3
#     nucliadb 2.7.0.post161 depends on tikv-client>=0.0.3
#     nucliadb 2.7.0.post160 depends on tikv-client>=0.0.3
#     nucliadb 2.7.0.post159 depends on tikv-client>=0.0.3
#     nucliadb 2.7.0.post158 depends on tikv-client>=0.0.3
#     nucliadb 2.7.0.post157 depends on tikv-client>=0.0.3
#     nucliadb 2.7.0.post156 depends on tikv-client>=0.0.3
#     nucliadb 2.7.0.post154 depends on tikv-client>=0.0.3
#     nucliadb 2.7.0.post153 depends on tikv-client>=0.0.3
#     nucliadb 2.7.0.post152 depends on tikv-client>=0.0.3
#     nucliadb 2.7.0.post151 depends on tikv-client>=0.0.3
#     nucliadb 2.7.0.post148 depends on tikv-client>=0.0.3
#     nucliadb 2.7.0.post147 depends on tikv-client>=0.0.3
#     nucliadb 2.7.0.post146 depends on tikv-client>=0.0.3
#     nucliadb 2.7.0.post145 depends on tikv-client>=0.0.3
#     nucliadb 2.7.0.post143 depends on tikv-client>=0.0.3
#     nucliadb 2.7.0.post142 depends on tikv-client>=0.0.3
#     nucliadb 2.7.0.post141 depends on tikv-client>=0.0.3
#     nucliadb 2.7.0.post139 depends on tikv-client>=0.0.3
#     nucliadb 2.7.0.post138 depends on tikv-client>=0.0.3
#     nucliadb 2.6.0.post136 depends on tikv-client>=0.0.3
#     nucliadb 2.6.0.post135 depends on tikv-client>=0.0.3
#     nucliadb 2.6.0.post134 depends on tikv-client>=0.0.3
#     nucliadb 2.6.0.post133 depends on tikv-client>=0.0.3
#     nucliadb 2.6.0.post132 depends on tikv-client>=0.0.3
#     nucliadb 2.6.0.post129 depends on tikv-client>=0.0.3
#     nucliadb 2.6.0.post128 depends on tikv-client>=0.0.3
#     nucliadb 2.6.0.post127 depends on tikv-client>=0.0.3
#     nucliadb 2.6.0.post126 depends on tikv-client>=0.0.3
#     nucliadb 2.6.0.post125 depends on tikv-client>=0.0.3
#     nucliadb 2.6.0.post124 depends on tikv-client>=0.0.3
#     nucliadb 2.6.0.post122 depends on tikv-client>=0.0.3
#     nucliadb 2.6.0.post121 depends on tikv-client>=0.0.3
#     nucliadb 2.6.0.post120 depends on tikv-client>=0.0.3
#     nucliadb 2.6.0.post119 depends on tikv-client>=0.0.3
#     nucliadb 2.6.0.post118 depends on tikv-client>=0.0.3
#     nucliadb 2.6.0.post117 depends on tikv-client>=0.0.3
#     nucliadb 2.6.0.post116 depends on tikv-client>=0.0.3
#     nucliadb 2.6.0.post115 depends on tikv-client>=0.0.3
#     nucliadb 2.6.0.post114 depends on tikv-client>=0.0.3
#     nucliadb 2.6.0.post113 depends on tikv-client>=0.0.3
#     nucliadb 2.6.0.post112 depends on tikv-client>=0.0.3
#     nucliadb 2.6.0.post111 depends on tikv-client>=0.0.3
#     nucliadb 2.6.0.post110 depends on tikv-client>=0.0.3
#     nucliadb 2.6.0.post109 depends on tikv-client>=0.0.3
#     nucliadb 2.6.0.post108 depends on tikv-client>=0.0.3
#     nucliadb 2.5.0.post107 depends on tikv-client>=0.0.3
#     nucliadb 2.5.0.post106 depends on tikv-client>=0.0.3
#     nucliadb 2.5.0.post105 depends on tikv-client>=0.0.3
#     nucliadb 2.5.0.post104 depends on tikv-client>=0.0.3
#     nucliadb 2.5.0.post103 depends on tikv-client>=0.0.3
#     nucliadb 2.5.0.post102 depends on tikv-client>=0.0.3
#     nucliadb 2.5.0.post101 depends on tikv-client>=0.0.3
#     nucliadb 2.5.0.post100 depends on tikv-client>=0.0.3
#     nucliadb 2.5.0.post99 depends on tikv-client>=0.0.3
#     nucliadb 2.5.0.post98 depends on tikv-client>=0.0.3
#     nucliadb 2.5.0.post96 depends on tikv-client>=0.0.3
#     nucliadb 2.5.0.post95 depends on tikv-client>=0.0.3
#     nucliadb 2.5.0.post94 depends on tikv-client>=0.0.3
#     nucliadb 2.5.0.post93 depends on tikv-client>=0.0.3
#     nucliadb 2.5.0.post92 depends on tikv-client>=0.0.3
#     nucliadb 2.5.0.post91 depends on tikv-client>=0.0.3
#     nucliadb 2.5.0.post89 depends on tikv-client>=0.0.3
#     nucliadb 2.5.0.post88 depends on tikv-client>=0.0.3
#     nucliadb 2.5.0.post83 depends on tikv-client>=0.0.3
#     nucliadb 2.5.0.post82 depends on tikv-client>=0.0.3
#     nucliadb 2.5.0.post81 depends on tikv-client>=0.0.3
#     nucliadb 2.5.0.post80 depends on tikv-client>=0.0.3
#     nucliadb 2.5.0.post79 depends on tikv-client>=0.0.3
#     nucliadb 2.5.0.post78 depends on tikv-client>=0.0.3
#     nucliadb 2.5.0.post76 depends on tikv-client>=0.0.3
#     nucliadb 2.5.0.post75 depends on tikv-client>=0.0.3
#     nucliadb 2.5.0.post74 depends on tikv-client>=0.0.3
#     nucliadb 2.5.0.post73 depends on tikv-client>=0.0.3
#     nucliadb 2.5.0.post72 depends on tikv-client>=0.0.3
#     nucliadb 2.5.0.post71 depends on tikv-client>=0.0.3
#     nucliadb 2.5.0.post70 depends on tikv-client>=0.0.3
#     nucliadb 2.5.0.post69 depends on tikv-client>=0.0.3
#     nucliadb 2.5.0.post68 depends on tikv-client>=0.0.3
#     nucliadb 2.5.0.post67 depends on tikv-client>=0.0.3
#     nucliadb 2.5.0.post66 depends on tikv-client>=0.0.3
#     nucliadb 2.5.0.post65 depends on tikv-client>=0.0.3
#     nucliadb 2.5.0.post64 depends on tikv-client>=0.0.3
#     nucliadb 2.5.0.post62 depends on tikv-client>=0.0.3
#     nucliadb 2.5.0.post61 depends on tikv-client>=0.0.3
#     nucliadb 2.5.0.post60 depends on tikv-client>=0.0.3
#     nucliadb 2.5.0.post59 depends on tikv-client>=0.0.3
#     nucliadb 2.5.0.post58 depends on tikv-client>=0.0.3
#     nucliadb 2.5.0.post57 depends on tikv-client>=0.0.3
#     nucliadb 2.5.0.post55 depends on tikv-client>=0.0.3
#     nucliadb 2.5.0.post54 depends on tikv-client>=0.0.3
#     nucliadb 2.5.0.post51 depends on tikv-client>=0.0.3
#     nucliadb 2.5.0.post50 depends on tikv-client>=0.0.3
#     nucliadb 2.5.0.post49 depends on tikv-client>=0.0.3
#     nucliadb 2.5.0.post48 depends on tikv-client>=0.0.3
#     nucliadb 2.5.0.post47 depends on tikv-client>=0.0.3
#     nucliadb 2.5.0.post46 depends on tikv-client>=0.0.3
#     nucliadb 2.4.0.post44 depends on tikv-client>=0.0.3
#     nucliadb 2.4.0.post43 depends on tikv-client>=0.0.3
#     nucliadb 2.4.0.post42 depends on tikv-client>=0.0.3
#     nucliadb 2.4.0.post27 depends on tikv-client>=0.0.3
#     nucliadb 2.4.0.post25 depends on tikv-client>=0.0.3
#     nucliadb 2.4.0.post24 depends on tikv-client>=0.0.3
#     nucliadb 2.4.0.post23 depends on tikv-client>=0.0.3
#     nucliadb 2.4.0.post22 depends on tikv-client>=0.0.3
#     nucliadb 2.4.0.post21 depends on tikv-client>=0.0.3
#     nucliadb 2.4.0.post20 depends on tikv-client>=0.0.3
#     nucliadb 2.4.0.post19 depends on tikv-client>=0.0.3
#     nucliadb 2.4.0.post18 depends on tikv-client>=0.0.3
#     nucliadb 2.4.0.post17 depends on tikv-client>=0.0.3
#     nucliadb 2.4.0.post16 depends on tikv-client>=0.0.3
#     nucliadb 2.3.0.post15 depends on tikv-client>=0.0.3
#     nucliadb 2.3.0.post14 depends on tikv-client>=0.0.3
#     nucliadb 2.3.0.post13 depends on tikv-client>=0.0.3
#     nucliadb 2.3.0.post12 depends on tikv-client>=0.0.3
#     nucliadb 2.3.0.post11 depends on tikv-client>=0.0.3
#     nucliadb 2.3.0.post10 depends on tikv-client>=0.0.3
#     nucliadb 2.3.0.post9 depends on tikv-client>=0.0.3
#     nucliadb 2.3.0.post8 depends on tikv-client>=0.0.3
#     nucliadb 2.3.0.post7 depends on tikv-client>=0.0.3
#     nucliadb 2.3.0.post5 depends on tikv-client>=0.0.3
#     nucliadb 2.2.5 depends on tikv-client>=0.0.3
#     nucliadb 2.2.4 depends on tikv-client>=0.0.3
#     nucliadb 2.2.3 depends on tikv-client>=0.0.3
#     nucliadb 2.2.2 depends on tikv-client>=0.0.3
#     nucliadb 2.2.1 depends on tikv-client>=0.0.3
#     nucliadb 2.2.0 depends on tikv-client>=0.0.3
#     nucliadb 2.1.0 depends on tikv-client>=0.0.3
#     nucliadb 2.0.15 depends on tikv-client>=0.0.3
#     nucliadb 2.0.14 depends on tikv-client>=0.0.3
#     nucliadb 2.0.13 depends on tikv-client>=0.0.3
#     nucliadb 2.0.12 depends on tikv-client>=0.0.3
#     nucliadb 2.0.11 depends on tikv-client>=0.0.3
#     nucliadb 2.0.10 depends on tikv-client>=0.0.3
#     nucliadb 2.0.9 depends on tikv-client>=0.0.3
#     nucliadb 2.0.8 depends on tikv-client>=0.0.3
#     nucliadb 2.0.7 depends on tikv-client>=0.0.3
#     nucliadb 2.0.6 depends on tikv-client>=0.0.3
#     nucliadb 2.0.5 depends on tikv-client>=0.0.3
#     nucliadb 2.0.4 depends on tikv-client>=0.0.3
#     nucliadb 2.0.3 depends on tikv-client>=0.0.3
#     nucliadb 2.0.2 depends on tikv-client>=0.0.3
#     nucliadb 0.0.1 depends on nucliadb-models==0.0.1
#     nucliadb 0.0.0.post2 depends on tikv-client>=0.0.3
#     nucliadb 0.0.0.post1 depends on nucliadb-utils[cache, fastapi and storages]==0.0.0-r1
#
# To fix this you could try to:
# 1. loosen the range of package versions you've specified
# 2. remove package versions to allow pip attempt to solve the dependency conflict

# %% [markdown]
# ### Check everything is up and running

# %%
import requests
response = requests.get(f"http://0.0.0.0:8080")
response
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# File c:\Users\Limo\anaconda3\envs\chartbotWhatsapp\Lib\site-packages\urllib3\connection.py:174, in HTTPConnection._new_conn(self)
#     173 try:
# --> 174     conn = connection.create_connection(
#     175         (self._dns_host, self.port), self.timeout, **extra_kw
#     176     )
#     178 except SocketTimeout:
#
# File c:\Users\Limo\anaconda3\envs\chartbotWhatsapp\Lib\site-packages\urllib3\util\connection.py:95, in create_connection(address, timeout, source_address, socket_options)
#      94 if err is not None:
# ---> 95     raise err
#      97 raise socket.error("getaddrinfo returns an empty list")
#
# File c:\Users\Limo\anaconda3\envs\chartbotWhatsapp\Lib\site-packages\urllib3\util\connection.py:85, in create_connection(address, timeout, source_address, socket_options)
#      84     sock.bind(source_address)
# ---> 85 sock.connect(sa)
#      86 return sock
#
# OSError: [WinError 10049] The requested address is not valid in its context
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# File c:\Users\Limo\anaconda3\envs\chartbotWhatsapp\Lib\site-packages\urllib3\connectionpool.py:714, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     713 # Make the request on the httplib connection object.
# --> 714 httplib_response = self._make_request(
#     715     conn,
#     716     method,
#     717     url,
#     718     timeout=timeout_obj,
#     719     body=body,
#     720     headers=headers,
#     721     chunked=chunked,
#     722 )
#     724 # If we're going to release the connection in ``finally:``, then
#     725 # the response doesn't need to know about the connection. Otherwise
#     726 # it will also try to release it and we'll have a double-release
#     727 # mess.
#
# File c:\Users\Limo\anaconda3\envs\chartbotWhatsapp\Lib\site-packages\urllib3\connectionpool.py:415, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     414     else:
# --> 415         conn.request(method, url, **httplib_request_kw)
#     417 # We are swallowing BrokenPipeError (errno.EPIPE) since the server is
#     418 # legitimately able to close the connection after sending a valid response.
#     419 # With this behaviour, the received response is still readable.
#
# File c:\Users\Limo\anaconda3\envs\chartbotWhatsapp\Lib\site-packages\urllib3\connection.py:244, in HTTPConnection.request(self, method, url, body, headers)
#     243     headers["User-Agent"] = _get_default_user_agent()
# --> 244 super(HTTPConnection, self).request(method, url, body=body, headers=headers)
#
# File c:\Users\Limo\anaconda3\envs\chartbotWhatsapp\Lib\http\client.py:1283, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1282 """Send a complete request to the server."""
# -> 1283 self._send_request(method, url, body, headers, encode_chunked)
#
# File c:\Users\Limo\anaconda3\envs\chartbotWhatsapp\Lib\http\client.py:1329, in HTTPConnection._send_request(self, method, url, body, headers, encode_chunked)
#    1328     body = _encode(body, 'body')
# -> 1329 self.endheaders(body, encode_chunked=encode_chunked)
#
# File c:\Users\Limo\anaconda3\envs\chartbotWhatsapp\Lib\http\client.py:1278, in HTTPConnection.endheaders(self, message_body, encode_chunked)
#    1277     raise CannotSendHeader()
# -> 1278 self._send_output(message_body, encode_chunked=encode_chunked)
#
# File c:\Users\Limo\anaconda3\envs\chartbotWhatsapp\Lib\http\client.py:1038, in HTTPConnection._send_output(self, message_body, encode_chunked)
#    1037 del self._buffer[:]
# -> 1038 self.send(msg)
#    1040 if message_body is not None:
#    1041
#    1042     # create a consistent interface to message_body
#
# File c:\Users\Limo\anaconda3\envs\chartbotWhatsapp\Lib\http\client.py:976, in HTTPConnection.send(self, data)
#     975 if self.auto_open:
# --> 976     self.connect()
#     977 else:
#
# File c:\Users\Limo\anaconda3\envs\chartbotWhatsapp\Lib\site-packages\urllib3\connection.py:205, in HTTPConnection.connect(self)
#     204 def connect(self):
# --> 205     conn = self._new_conn()
#     206     self._prepare_conn(conn)
#
# File c:\Users\Limo\anaconda3\envs\chartbotWhatsapp\Lib\site-packages\urllib3\connection.py:186, in HTTPConnection._new_conn(self)
#     185 except SocketError as e:
# --> 186     raise NewConnectionError(
#     187         self, "Failed to establish a new connection: %s" % e
#     188     )
#     190 return conn
#
# NewConnectionError: <urllib3.connection.HTTPConnection object at 0x0000013E773B07D0>: Failed to establish a new connection: [WinError 10049] The requested address is not valid in its context
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# File c:\Users\Limo\anaconda3\envs\chartbotWhatsapp\Lib\site-packages\requests\adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#
# File c:\Users\Limo\anaconda3\envs\chartbotWhatsapp\Lib\site-packages\urllib3\connectionpool.py:798, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     796     e = ProtocolError("Connection aborted.", e)
# --> 798 retries = retries.increment(
#     799     method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     800 )
#     801 retries.sleep()
#
# File c:\Users\Limo\anaconda3\envs\chartbotWhatsapp\Lib\site-packages\urllib3\util\retry.py:592, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     591 if new_retry.is_exhausted():
# --> 592     raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     594 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPConnectionPool(host='0.0.0.0', port=8080): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x0000013E773B07D0>: Failed to establish a new connection: [WinError 10049] The requested address is not valid in its context'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# Cell In[4], line 2
#       1 import requests
# ----> 2 response = requests.get(f"http://0.0.0.0:8080")
#       3 response
#
# File c:\Users\Limo\anaconda3\envs\chartbotWhatsapp\Lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File c:\Users\Limo\anaconda3\envs\chartbotWhatsapp\Lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File c:\Users\Limo\anaconda3\envs\chartbotWhatsapp\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File c:\Users\Limo\anaconda3\envs\chartbotWhatsapp\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File c:\Users\Limo\anaconda3\envs\chartbotWhatsapp\Lib\site-packages\requests\adapters.py:519, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     515     if isinstance(e.reason, _SSLError):
#     516         # This branch is for urllib3 v1.22 and later.
#     517         raise SSLError(e, request=request)
# --> 519     raise ConnectionError(e, request=request)
#     521 except ClosedPoolError as e:
#     522     raise ConnectionError(e, request=request)
#
# ConnectionError: HTTPConnectionPool(host='0.0.0.0', port=8080): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x0000013E773B07D0>: Failed to establish a new connection: [WinError 10049] The requested address is not valid in its context'))
